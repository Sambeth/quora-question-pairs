# %%
# necessary imports
import re
import unicodedata
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import matplotlib.pyplot as plt
import contractions
import inflect
# from autocorrect import spell
from fuzzywuzzy import fuzz
import gensim

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split, KFold, cross_val_score
from sklearn.metrics import log_loss, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from xgboost import XGBClassifier

from gensim.models import KeyedVectors
from scipy.special import expit

# %matplotlib inline

# %%
stop_words = stopwords.words('english')

# %%
# setting paths to the dataset
train = 'data/train.csv'
test = 'data/test.csv'

# %%
train_data = pd.read_csv(train)
test_data = pd.read_csv(test)

# %%
train_data.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
test_data.head()
# Out:
#    test_id                                          question1  \
# 0        0  How does the Surface Pro himself 4 compare wit...
# 1        1  Should I have a hair transplant at age 24? How...
# 2        2  What but is the best way to send money from Ch...
# 3        3                        Which food not emulsifiers?
# 4        4                   How "aberystwyth" start reading?
#
#                                            question2
# 0  Why did Microsoft choose core m3 and not core ...
# 1        How much cost does hair transplant require?
# 2                      What you send money to China?
# 3                                  What foods fibre?
# 4                     How their can I start reading?

# %%
train_data.shape, test_data.shape
# Out:
# ((404290, 6), (2345796, 3))

# %% [markdown]
# Over 400000 rows of data to work with. Let's view the number of duplicated questions.

# %%
is_duplicate = train_data['is_duplicate'] == 1
is_duplicate.value_counts()
# Out:
# False    255027
# True     149263
# Name: is_duplicate, dtype: int64

# %%
duplicate_df = pd.DataFrame([is_duplicate.value_counts().values[0], is_duplicate.value_counts().values[1]])
duplicate_df.index = ['Non-Duplicate', 'Duplicate']
# duplicate_df.T
duplicate_df.T.plot(kind='bar', figsize=(15,8))

# %%
# lets get the percentage of duplicates
percent = (is_duplicate.value_counts().values[1] / train_data.shape[0]) * 100
print(f'The percentage of duplicated question pairs is {percent}%')
# Out:
# The percentage of duplicated question pairs is 36.9197853026293%

# %% [markdown]
# **Text Preprocessing**
#
# This the first step to solving the problem at hand. I will consider the following techniques;
#
# *   Noise removal
# *   Processing contractions
# *   Tokenization
# *   Normalization
# *   Noise removal

# %% [markdown]
# The initial noise removal will be to remove beginning and trailing white spaces if it happens to be the case

# %%
# lets make sure none of the questions has beginning and trailing whitespaces
def remove_white_spaces(text):
  '''
  Remove beginning and trailing whitespaces from text
  '''
  return text.strip()

# %% [markdown]
# Contractions will also be replaced. For instance "didn't" will become "did not"

# %%
# let replace all contractions. for instance "didn't" to "did not"
def replace_contractions(text):
  '''
  Replace contractions in a text
  '''
  return contractions.fix(text)

# %% [markdown]
# Next, each question will be tokenized into token.

# %%
# next we tokenize each question which is to split the words that make up a question into tokens or split questions into words
def tokenize_words(text):
  '''
  Split questions into words
  '''
  return nltk.word_tokenize(text)

# %% [markdown]
# For the normalization stage, a  number of techniques will be used.
#
#
#
# *   Lemmatization
# *   Remove non-ascii words
# *   Replace number symbols with words
# *   Convert words to lowercase
# *   Remove punctuations

# %%
# lemmatization is converting word to it's dictionary base form
def lemmatize(words):
    '''
    Convert words to base dict form
    '''
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

# %%
# characters that are non-ascii will be removed
def remove_non_ascii(words):
    '''
    Remove non-ascii characters from list of words
    '''
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

# %%
# the number `1` becomes 'one'
def replace_numbers(words):
    '''
    Replace integers in list of words from symbolic form to text form
    '''
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

# %%
# convert words to lowercase
def to_lowercase(words):
    '''
    Convert all characters to lowercase
    '''
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

# %%
# remove punctuations
def remove_punctuation(words):
    '''
    Remove punctuation from words
    '''
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

# %%
def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    return words

# %%
# finally we remove stop words
def remove_stopwords(words):
    '''
    Remove stop words from list of words
    '''
    new_words = []
    for word in words:
        if word not in stop_words:
            new_words.append(word)
    return new_words

# %%
# for question1 column
train_data['question1'] = train_data['question1'].apply(lambda text: remove_white_spaces(str(text)))
train_data['question1'] = train_data['question1'].apply(lambda text: replace_contractions(str(text)))
train_data['question1'] = train_data['question1'].apply(lambda text: tokenize_words(text))
train_data['question1'] = train_data['question1'].apply(lambda words: normalize(words))
train_data['question1'] = train_data['question1'].apply(lambda words: lemmatize(words))
train_data['question1'] = train_data['question1'].apply(lambda words: remove_stopwords(words))

# for question2 column
train_data['question2'] = train_data['question2'].apply(lambda text: remove_white_spaces(str(text)))
train_data['question2'] = train_data['question2'].apply(lambda text: replace_contractions(str(text)))
train_data['question2'] = train_data['question2'].apply(lambda text: tokenize_words(text))
train_data['question2'] = train_data['question2'].apply(lambda words: normalize(words))
train_data['question2'] = train_data['question2'].apply(lambda words: lemmatize(words))
train_data['question2'] = train_data['question2'].apply(lambda words: remove_stopwords(words))

# %%
train_data.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  [step, step, guide, invest, share, market, india]
# 1   1     3     4               [story, kohinoor, kohinoor, diamond]
# 2   2     5     6  [increase, speed, internet, connection, use, vpn]
# 3   3     7     8                          [mentally, lonely, solve]
# 4   4     9    10  [one, dissolve, water, quikly, sugar, salt, me...
#
#                                            question2  is_duplicate
# 0         [step, step, guide, invest, share, market]             0
# 1  [would, happen, indian, government, steal, koh...             0
# 2             [internet, speed, increase, hack, dns]             0
# 3  [find, remainder, math, twenty-three, twenty-f...             0
# 4                [fish, would, survive, salt, water]             0

# %%
unwanted_columns = ['id', 'qid1', 'qid2']
data = train_data.drop(unwanted_columns, axis=1)

# %%
data.head()
# Out:
#                                            question1  \
# 0  [step, step, guide, invest, share, market, india]
# 1               [story, kohinoor, kohinoor, diamond]
# 2  [increase, speed, internet, connection, use, vpn]
# 3                          [mentally, lonely, solve]
# 4  [one, dissolve, water, quikly, sugar, salt, me...
#
#                                            question2  is_duplicate
# 0         [step, step, guide, invest, share, market]             0
# 1  [would, happen, indian, government, steal, koh...             0
# 2             [internet, speed, increase, hack, dns]             0
# 3  [find, remainder, math, twenty-three, twenty-f...             0
# 4                [fish, would, survive, salt, water]             0

# %% [markdown]
# **Featuere Extraction/Engineering**
#
# Here, a number of features will be created from the preprocessed texts.
#
# Metadata
#
# *   length of each question
# *   differences in  length
# *   common words in each pair of question
# *   length of characters in each question
# *   length of words in each question
#
# *   string similarity
# *   partial string similarity

# %%
# text metadata
data['len_q1'] = data['question1'].apply(lambda words: len(words))
data['len_q2'] = data['question2'].apply(lambda words: len(words))
data['diff_len'] = data.len_q1 - data.len_q2
data['common_words'] = data.apply(lambda words: len(set(words['question1']).intersection(set(words['question2']))), axis=1)
data['len_char_q1'] = data['question1'].apply(lambda words: len(set(''.join(words))))
data['len_char_q2'] = data['question2'].apply(lambda words: len(set(''.join(words))))

# fuzzywuzzy
data['ratio'] = data.apply(lambda x: fuzz.ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['partial_ratio'] = data.apply(lambda x: fuzz.partial_ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['token_sort_ratio'] = data.apply(lambda x: fuzz.token_sort_ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['token_set_ratio'] = data.apply(lambda x: fuzz.token_set_ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['qratio'] = data.apply(lambda x: fuzz.QRatio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['wratio'] = data.apply(lambda x: fuzz.WRatio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['partial_token_sort_ratio'] = data.apply(lambda x: fuzz.partial_token_set_ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)
data['partial_token_set_ratio'] = data.apply(lambda x: fuzz.partial_token_set_ratio(' '.join(x['question1']), ' '.join(x['question2'])), axis=1)

# %%
data.head()
# Out:
#                                            question1  \
# 0  [step, step, guide, invest, share, market, india]
# 1               [story, kohinoor, kohinoor, diamond]
# 2  [increase, speed, internet, connection, use, vpn]
# 3                          [mentally, lonely, solve]
# 4  [one, dissolve, water, quikly, sugar, salt, me...
#
#                                            question2  is_duplicate  len_q1  \
# 0         [step, step, guide, invest, share, market]             0       7
# 1  [would, happen, indian, government, steal, koh...             0       4
# 2             [internet, speed, increase, hack, dns]             0       6
# 3  [find, remainder, math, twenty-three, twenty-f...             0       3
# 4                [fish, would, survive, salt, water]             0      10
#
#    len_q2  diff_len  common_words  len_char_q1  len_char_q2  ratio  \
# 0       6         1             5           15           15     92
# 1       9        -5             2           12           20     57
# 2       5         1             3           13           12     51
# 3       8        -5             0           10           19     20
# 4       5         5             2           22           14     43
#
#    partial_ratio  token_sort_ratio  token_set_ratio  qratio  wratio  \
# 0            100                92              100      92      95
# 1             90                59               84      57      86
# 2             56                70               84      51      80
# 3             38                20               27      20      41
# 4             52                40               51      43      86
#
#    partial_token_sort_ratio  partial_token_set_ratio
# 0                       100                      100
# 1                       100                      100
# 2                       100                      100
# 3                        43                       43
# 4                       100                      100

# %% [markdown]
# With the new featuers lets can check how wrong the human generated labels are with respect to:
#
# * Difference in question length
# * Partial ratio
# * Token set ratio
#
# More imformation on the fuzzywuzzy features can be found [here](http://chairnerd.seatgeek.com/fuzzywuzzy-fuzzy-string-matching-in-python/)

# %%
data[data['diff_len'] <= 5]['is_duplicate'].value_counts()
# Out:
# 0    242672
# 1    147990
# Name: is_duplicate, dtype: int64

# %%
# assuming duplicated questions have a difference in length less than 5
duplicate_df = pd.DataFrame([data[data['diff_len'] <= 5]['is_duplicate'].value_counts().values[0], data[data['diff_len'] < 5]['is_duplicate'].value_counts().values[1]])
duplicate_df.index = ['Non-Duplicate', 'Duplicate']
# duplicate_df.T
duplicate_df.T.plot(kind='bar', figsize=(15,8))

# %%
print(data[data['diff_len'] <= 5]['is_duplicate'].value_counts().values[0], data[data['diff_len'] < 5]['is_duplicate'].value_counts().values[1])
print(is_duplicate.value_counts().values[0], is_duplicate.value_counts().values[1])
# Out:
# 242645 146797
# 255027 149263

# %%
data.describe()
# Out:
#         is_duplicate         len_q1         len_q2       diff_len  \
# count  404290.000000  404290.000000  404290.000000  404290.000000
# mean        0.369198       5.454790       5.522565      -0.067776
# std         0.482588       2.948506       3.247303       3.077137
# min         0.000000       0.000000       0.000000     -90.000000
# 25%         0.000000       3.000000       3.000000      -1.000000
# 50%         0.000000       5.000000       5.000000       0.000000
# 75%         1.000000       7.000000       7.000000       1.000000
# max         1.000000      53.000000      99.000000      44.000000
#
#         common_words    len_char_q1    len_char_q2          ratio  \
# count  404290.000000  404290.000000  404290.000000  404290.000000
# mean        2.596186      14.311094      14.247703      62.446160
# std         1.679733       3.591929       3.661004      20.495043
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000      12.000000      12.000000      46.000000
# 50%         2.000000      14.000000      14.000000      62.000000
# 75%         3.000000      17.000000      17.000000      79.000000
# max        24.000000      35.000000      34.000000     100.000000
#
#        partial_ratio  token_sort_ratio  token_set_ratio         qratio  \
# count  404290.000000     404290.000000    404290.000000  404290.000000
# mean       70.221514         64.671716        75.962557      62.454424
# std        20.037914         19.814359        21.253734      20.488127
# min         0.000000          0.000000         0.000000       0.000000
# 25%        54.000000         50.000000        62.000000      46.000000
# 50%        70.000000         65.000000        80.000000      62.000000
# 75%        86.000000         80.000000        96.000000      79.000000
# max       100.000000        100.000000       100.000000     100.000000
#
#               wratio  partial_token_sort_ratio  partial_token_set_ratio
# count  404290.000000             404290.000000            404290.000000
# mean       77.569626                 94.523674                94.523674
# std        17.873450                 17.214385                17.214385
# min         0.000000                  0.000000                 0.000000
# 25%        68.000000                100.000000               100.000000
# 50%        86.000000                100.000000               100.000000
# 75%        89.000000                100.000000               100.000000
# max       100.000000                100.000000               100.000000

# %%
# assuming duplicated questions have a partial ratio from 75th percentile onwards
duplicate_df = pd.DataFrame([data[data['partial_ratio'] > 85]['is_duplicate'].value_counts().values[0], data[data['partial_ratio'] < 85]['is_duplicate'].value_counts().values[1]])
duplicate_df.index = ['Non-Duplicate', 'Duplicate']
# duplicate_df.T
duplicate_df.T.plot(kind='bar', figsize=(15,8))

# %% [markdown]
# Over 80000 data points rightly labelled according the partial ratio feature.

# %%
# assuming duplicated questions have a partial ratio in above 75th percentile
duplicate_df = pd.DataFrame([data[data['token_set_ratio'] > 92]['is_duplicate'].value_counts().values[0], data[data['partial_ratio'] < 92]['token_set_ratio'].value_counts().values[1]])
duplicate_df.index = ['Non-Duplicate', 'Duplicate']
# duplicate_df.T
duplicate_df.T.plot(kind='bar', figsize=(15,8))

# %% [markdown]
# More than 10000 data points wrongly labelled according the the token set ratio.

# %% [markdown]
# **WORD2VEC FEATURE EXTRACTION**

# %%
word2vec_file = 'glove.6B.300d.txt.word2vec'

# %%
model = KeyedVectors.load_word2vec_format(word2vec_file, binary=False)

# %%
def word_similarity(x1, x2):
    '''
    Check each word in a question pair against each other for similarity and squash it between 0 and 1.
    Hence, very similar questions have a scopre closer to one and vice versa.
    '''
    similarity = []
    for word1 in x1:
        for word2 in x2:
            try:
                similarity.append(model.similarity(word1, word2))
            except KeyError as e:
                continue
    return expit(sum(similarity))

# %%
data['word_similarity'] = data.apply(lambda x: word_similarity(x['question1'], x['question2']), axis=1)

# %%
unwanted_columns = ['question1', 'question2']

training_data = data.drop(unwanted_columns, axis=1)
X = training_data.drop(['is_duplicate'], axis=1)
Y = training_data['is_duplicate']

# %% [markdown]
# **Machine Learning Models with Word2Vec Feattures**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)

# %%
scoring = make_scorer(log_loss, needs_proba=True, greater_is_better=False)

# %%
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()), ('LR', LogisticRegression())])))
pipelines.append(('ScaledRF', Pipeline([('Scaler', StandardScaler()), ('RF', RandomForestClassifier())])))
pipelines.append(('ScaledXG', Pipeline([('Scaler', StandardScaler()), ('XG', XGBClassifier())])))

results = []
names = []

for name, model in pipelines:
    kfold = KFold(n_splits=10, random_state=42)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ScaledLR: -0.532948 (0.002666)
# ScaledRF: -0.978139 (0.031121)
# ScaledXG: -0.491490 (0.002421)

# %% [markdown]
# The XGBClassifier was the better model here so it can further be tuned to get a better log loss score. RandomForestClassifier performed poorly because it does not work well with sparse datasets. The benchmark model is to get a log loss score below `0.4`.

# %%
# xgboostclassifier
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)

kfold = KFold(n_splits=10, random_state=42)

max_depth = [3, 4, 5, 6, 7, 8]
min_child_weight = [1, 2, 3, 4]
param_grid = dict(max_depth=max_depth, min_child_weight=min_child_weight)

model = XGBClassifier()

grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(scaled_X_train, y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.467980 using {'max_depth': 8, 'min_child_weight': 1}
# -0.491531 (0.002413) with: {'max_depth': 3, 'min_child_weight': 1}
# -0.491382 (0.002507) with: {'max_depth': 3, 'min_child_weight': 2}
# -0.491456 (0.002597) with: {'max_depth': 3, 'min_child_weight': 3}
# -0.491640 (0.002299) with: {'max_depth': 3, 'min_child_weight': 4}
# -0.483421 (0.002538) with: {'max_depth': 4, 'min_child_weight': 1}
# -0.483353 (0.002552) with: {'max_depth': 4, 'min_child_weight': 2}
# -0.483352 (0.002591) with: {'max_depth': 4, 'min_child_weight': 3}
# -0.483276 (0.002412) with: {'max_depth': 4, 'min_child_weight': 4}
# -0.477563 (0.002503) with: {'max_depth': 5, 'min_child_weight': 1}
# -0.477616 (0.002649) with: {'max_depth': 5, 'min_child_weight': 2}
# -0.477764 (0.002562) with: {'max_depth': 5, 'min_child_weight': 3}
# -0.477633 (0.002638) with: {'max_depth': 5, 'min_child_weight': 4}
# -0.473465 (0.002548) with: {'max_depth': 6, 'min_child_weight': 1}
# -0.473475 (0.002732) with: {'max_depth': 6, 'min_child_weight': 2}
# -0.473443 (0.002730) with: {'max_depth': 6, 'min_child_weight': 3}
# -0.473555 (0.002651) with: {'max_depth': 6, 'min_child_weight': 4}
# -0.470397 (0.002624) with: {'max_depth': 7, 'min_child_weight': 1}
# -0.470537 (0.002699) with: {'max_depth': 7, 'min_child_weight': 2}
# -0.470381 (0.002399) with: {'max_depth': 7, 'min_child_weight': 3}
# -0.470583 (0.002679) with: {'max_depth': 7, 'min_child_weight': 4}
# -0.467980 (0.002429) with: {'max_depth': 8, 'min_child_weight': 1}
# -0.468088 (0.002486) with: {'max_depth': 8, 'min_child_weight': 2}
# -0.468335 (0.002648) with: {'max_depth': 8, 'min_child_weight': 3}
# -0.468212 (0.002620) with: {'max_depth': 8, 'min_child_weight': 4}

# %% [markdown]
# The log loss score has improved. Maybe it can be further be improved with a better larger `max_depth` argument but I would make due with what I got and improve it later.

# %% [markdown]
# Lets add more features to see if the model improves. Next will be to generate the tf-idf vectorizer for the dataset.

# %%
# join question1 and question2 columns to one axis
train_data_q1, train_data_q2 = data[['question1']], data[['question2']]
print(f'Length of Question 1: {len(train_data_q1)}, \nLength of Question 2: {len(train_data_q2)} \nTotal: {len(train_data_q1)+len(train_data_q2)}')
train_data_q1.columns, train_data_q2.columns = ['question'], ['question'] 
train_q = pd.concat([train_data_q1, train_data_q2], ignore_index=True, axis=0)
# Out:
# Length of Question 1: 404290,
# Length of Question 2: 404290
# Total: 808580

# %%
train_q.head()
# Out:
#                                             question
# 0  [step, step, guide, invest, share, market, india]
# 1               [story, kohinoor, kohinoor, diamond]
# 2  [increase, speed, internet, connection, using,...
# 3                          [mentally, lonely, solve]
# 4  [one, dissolve, water, quikly, sugar, salt, me...

# %%
# prepare question values for tfidfvectorizer
docs = []
for q in train_q.values:
    docs.append(*q)
docs
# Out:
# [['step', 'step', 'guide', 'invest', 'share', 'market', 'india'],
#  ['story', 'kohinoor', 'kohinoor', 'diamond'],
#  ['increase', 'speed', 'internet', 'connection', 'using', 'vpn'],
#  ['mentally', 'lonely', 'solve'],
#  ['one',
#   'dissolve',
#   'water',
#   'quikly',
#   'sugar',
#   'salt',
#   'methane',
#   'carbon',
#   'di',
#   'oxide'],
#  ['astrology', 'capricorn', 'sun', 'cap', 'moon', 'cap', 'rising', 'say'],
#  ['buy', 'tiago'],
#  ['good', 'geologist'],
#  ['use', 'instead'],
#  ['motorola', 'company', 'hack', 'charter', 'motorolla', 'dcx3400'],
#  ['method', 'find', 'separation', 'slits', 'using', 'fresnel', 'biprism'],
#  ['read', 'find', 'youtube', 'comments'],
#  ['make', 'physics', 'easy', 'learn'],
#  ['first', 'sexual', 'experience', 'like'],
#  ['laws',
#   'change',
#   'status',
#   'student',
#   'visa',
#   'green',
#   'card',
#   'us',
#   'compare',
#   'immigration',
#   'laws',
#   'canada'],
#  ['would',
#   'trump',
#   'presidency',
#   'mean',
#   'current',
#   'international',
#   'master',
#   'students',
#   'f1',
#   'visa'],
#  ['manipulation', 'mean'],
#  ['girls', 'want', 'friends', 'guy', 'reject'],
#  ['many',
#   'quora',
#   'users',
#   'posting',
#   'questions',
#   'readily',
#   'answered',
#   'google'],
#  ['best', 'digital', 'marketing', 'institution', 'banglore'],
#  ['rockets', 'look', 'white'],
#  ['causing', 'someone', 'jealous'],
#  ['questions', 'ask', 'quora'],
#  ['much', 'thirty', 'kv', 'hp'],
#  ['mean', 'every', 'time', 'look', 'clock', 'numbers'],
#  ['tips', 'making', 'job', 'interview', 'process', 'medicines'],
#  ['web', 'application'],
#  ['society', 'place', 'much', 'importance', 'sports'],
#  ['best', 'way', 'make', 'money', 'online'],
#  ['prepare', 'ca', 'final', 'law'],
#  ['one', 'thing', 'would', 'like', 'better'],
#  ['special', 'cares', 'someone', 'nose', 'gets', 'stuffy', 'night'],
#  ['game', 'thrones', 'villain', 'would', 'likely', 'give', 'mercy'],
#  ['united',
#   'states',
#   'government',
#   'still',
#   'blacklist',
#   'employment',
#   'etc',
#   'united',
#   'states',
#   'citizens',
#   'political',
#   'views'],
#  ['best', 'travel', 'website', 'spain'],
#  ['people', 'think', 'obama', 'try', 'take', 'guns', 'away'],
#  ['19yearold', 'improve', 'skills', 'become', 'entrepreneur', 'next', 'years'],
#  ['girlfriend',
#   'asks',
#   'boyfriend',
#   'choose',
#   'makes',
#   'want',
#   'one',
#   'reply'],
#  ['prepare', 'upsc'],
#  ['stall', 'speed', 'aoa', 'f14', 'wings', 'fully', 'swept', 'back'],
#  ['slavs', 'squat'],
#  ['expect', 'cognizant', 'confirmation', 'mail'],
#  ['make', 'fifty thousand', 'month', 'day', 'trading'],
#  ['good', 'kid', 'rebel', 'worth', 'long', 'run'],
#  ['universities', 'rexnord', 'recruit', 'new', 'grads', 'majors', 'looking'],
#  ['quickest', 'way', 'increase', 'instagram', 'followers'],
#  ['darth', 'vader', 'fought', 'darth', 'maul', 'star', 'wars', 'legends'],
#  ['stages',
#   'breaking',
#   'couple',
#   'mean',
#   'happens',
#   'breaking',
#   'emotionally',
#   'whether',
#   'male',
#   'female'],
#  ['examples', 'products', 'make', 'crude', 'oil'],
#  ['make', 'friends'],
#  ['career', 'launcher', 'good', 'rbi', 'grade', 'b', 'preparation'],
#  ['blu', 'ray', 'play', 'regular', 'dvd', 'player'],
#  ['nd', 'always', 'sad'],
#  ['bestmost', 'memorable', 'thing', 'ever', 'eaten'],
#  ['gst', 'affects', 'cas', 'tax', 'officers'],
#  ['difficult', 'get', 'rsi'],
#  ['israil', 'friend'],
#  ['good', 'rap', 'songs', 'dance'],
#  ['suddenly',
#   'logged',
#   'gmail',
#   'remember',
#   'gmail',
#   'password',
#   'realized',
#   'recovery',
#   'email',
#   'longer',
#   'alive'],
#  ['best', 'ways', 'learn', 'french'],
#  ['download', 'content', 'kickass', 'torrent', 'without', 'registration'],
#  ['normal', 'dark', 'ring', 'around', 'iris', 'eye'],
#  ['new', 'harry', 'potter', 'book', 'harry', 'potter', 'cursed', 'child'],
#  ['always', 'get', 'depressed'],
#  ['find', 'european', 'family', 'office', 'database'],
#  ['java', 'programming', 'learn', 'java', 'programming', 'language'],
#  ['best', 'book', 'ever', 'made'],
#  ['ever', 'store', 'energy', 'produced', 'lightning'],
#  ['review', 'performance', 'testing'],
#  ['cost',
#   'much',
#   'privacy',
#   'germany',
#   'come',
#   'else',
#   'lost',
#   'gain',
#   'much',
#   'privacy'],
#  ['types', 'immunity'],
#  ['narcissistic', 'personality', 'disorder'],
#  ['speak', 'english', 'fluently'],
#  ['helpful',
#   'quickbooks',
#   'auto',
#   'data',
#   'recovery',
#   'support',
#   'phone',
#   'number',
#   'recover',
#   'corrupted',
#   'data',
#   'files'],
#  ['richest', 'gambler', 'time', 'reach', 'level'],
#  ['fire',
#   'bullet',
#   'backward',
#   'aircraft',
#   'going',
#   'faster',
#   'bullet',
#   'bullet',
#   'going',
#   'backwards'],
#  ['prevent', 'breast', 'cancer'],
#  ['log', 'gmail', 'account', 'friend', 'phone'],
#  ['make', 'money', 'internet'],
#  ['purpose', 'life'],
#  ['bjp',
#   'government',
#   'strip',
#   'muslims',
#   'christians',
#   'indian',
#   'citizenship',
#   'put',
#   'boats',
#   'like',
#   'rohingya',
#   'burma'],
#  ['right', 'etiquette', 'wishing', 'jehovah', 'witness', 'happy', 'birthday'],
#  ['someone',
#   'wants',
#   'open',
#   'commercial',
#   'fm',
#   'radio',
#   'station',
#   'city',
#   'india',
#   'much',
#   'cost',
#   'procedure'],
#  ['swiss', 'despise', 'asians'],
#  ['high', 'salary', 'income', 'jobs', 'field', 'biotechnology'],
#  ['increase', 'height', 'twentyone', 'also'],
#  ['major',
#   'effects',
#   'cambodia',
#   'earthquake',
#   'effects',
#   'compare',
#   'kamchatca',
#   'earthquakes',
#   'one thousand nine hundred and fiftytwo'],
#  ['difference', 'sincerity', 'fairness'],
#  ['best', 'gaming', 'laptop', '60k', 'inr'],
#  ['review', 'next', 'warrior', 'proving', 'grounds', 'part', 'nine'],
#  ['best', 'reference', 'book', 'physics', 'class', '11th'],
#  ['national',
#   'institute',
#   'technology',
#   'kurukshetra',
#   'social',
#   'life',
#   'nitk',
#   'surathkal'],
#  ['best', 'romantic', 'movies', 'english'],
#  ['causes', 'nightmare'],
#  ['abstract', 'expressionism', 'painting'],
#  ['3d', 'printing', 'work'],
#  ['like', 'attend', 'caltech', 'jeremy', 'ehrhardt'],
#  ['harry', 'become', 'horcrux'],
#  ['best',
#   'associate',
#   'product',
#   'manager',
#   'apm',
#   'programs',
#   'someone',
#   'early',
#   '20s',
#   'join',
#   'learn',
#   'product',
#   'management',
#   'rewarding',
#   'career',
#   'company'],
#  ['number',
#   'skype',
#   'eighteen billion five hundred and fiftyfour million two hundred and fiftythree thousand seven hundred and sixtyeight',
#   'always',
#   'busy'],
#  ['really', 'war', 'india', 'pakistan', 'uri', 'attack', 'effects'],
#  ['ronald', 'reagan', 'mannerism', 'speech'],
#  ['war', 'strategies', 'union', 'confederates', 'civil', 'war'],
#  ['best', 'fiction', 'novel', 'two thousand and sixteen'],
#  ['recover', 'email', 'forgot', 'password'],
#  ['recent', 'demonetisation', 'results', 'higher', 'gdp', 'much'],
#  ['ever', 'heard', 'travel', 'hacking'],
#  ['difference', 'love', 'pity'],
#  ['competitive', 'hiring', 'process', 'republic', 'bank'],
#  ['google', 'helps', 'spam', 'ranking', 'adjustment', 'search', 'results'],
#  ['watch', 'gonulcelen', 'english', 'subtitles'],
#  ['usa', 'powerful', 'country', 'world'],
#  ['obtain', 'instant', 'ulcer', 'pain', 'relief'],
#  ['think', 'china', 'food'],
#  ['taking', 'advantage', 'someone', 'mean'],
#  ['cry', 'happy', 'sad'],
#  ['girls', 'like', 'stick', 'tongues', 'taking', 'pictures'],
#  ['find',
#   'ending',
#   'novel',
#   'one thousand nine hundred and eightyfour',
#   'depressing'],
#  ['mindblowing', 'computer', 'tools', 'exist', 'people', 'know'],
#  ['toothbrush', 'wet', 'dry', 'applying', 'toothpaste'],
#  ['question', 'marked', 'needing', 'imrovement'],
#  ['difference', 'neutral', 'state', 'buffer', 'state'],
#  ['mineral', 'holds', 'highest', 'electrical', 'charge'],
#  ['greatest', 'mystery', 'universe'],
#  ['alternative', 'machine', 'learning'],
#  ['china',
#   'block',
#   'sanctions',
#   'un',
#   'jaishemohammad',
#   'jem',
#   'chief',
#   'masood',
#   'azhar'],
#  ['mean', 'future', 'budget'],
#  ['excessive', 'amounts', 'vitamin', 'c', 'miscarriage'],
#  ['like',
#   'work',
#   'asahi',
#   'india',
#   'glass',
#   'pay',
#   'scale',
#   'one',
#   'two',
#   'years'],
#  ['access', 'torbox', 'india'],
#  ['yakshini', 'mantras'],
#  ['six', 'party', 'talks', 'successful'],
#  ['register', 'domain', 'site', 'email'],
#  ['normal', 'older', 'men', 'attracted', 'young', 'women'],
#  ['strongest', 'structure', 'strongest', 'shape', 'compression'],
#  ['rohingya', 'muslims'],
#  ['matter', 'whether', 'humans', 'selfish', 'evil'],
#  ['exocytosis', 'endocytosis', 'examples', 'active', 'passive', 'transport'],
#  ['get', 'hair', 'bald', 'head'],
#  ['ideal', 'life', 'retirement'],
#  ['stance', 'pakistan'],
#  ['good', 'websites', 'escorts'],
#  ['one', 'better', 'polo', 'diesel', 'grand', 'i10', 'petrol'],
#  ['black', 'hole', 'mass'],
#  ['morgan',
#   'freeman',
#   'correct',
#   'says',
#   'way',
#   'stop',
#   'racism',
#   'stop',
#   'talking'],
#  ['fab', 'currently', 'offer', 'new', 'employees', 'stock', 'options', 'rsus'],
#  ['would', 'review', 'site', 'waveclues'],
#  ['many',
#   'ways',
#   'distribute',
#   'ten',
#   'identical',
#   'looking',
#   'pencils',
#   'four',
#   'students',
#   'student',
#   'gets',
#   'least',
#   'one',
#   'pencil'],
#  ['much', 'would', 'cost', 'hire', 'jerry', 'seinfeld', 'twelve', 'hours'],
#  ['seven',
#   'days',
#   'late',
#   'rabies',
#   'vaccine',
#   'possible',
#   'nonbite',
#   'exposure'],
#  ['many', 'years', 'britain', 'ruled', 'india'],
#  ['stop', 'afraid', 'working'],
#  ['red', 'keep', 'keys', 'oitnb'],
#  ['age', 'someone', 'lose', 'virginity'],
#  ['forgetful'],
#  ['could', 'snoke', 'secretly', 'darth', 'maul'],
#  ['monetize',
#   'youtube',
#   'videos',
#   'upload',
#   'copyright',
#   'content',
#   'chances',
#   'google',
#   'may',
#   'block',
#   'account'],
#  ['would', 'switch', 'canon', '6d', 'leica', 'dlux', 'one hundred and nine'],
#  ['quora', 'website', 'look', 'like', 'members', 'quora', 'moderation'],
#  ['nobody', 'answer', 'questions', 'quora'],
#  ['funniest', 'joke', 'know'],
#  ['got',
#   'job',
#   'offer',
#   'chelmsfordessex',
#   'london',
#   'three thousand seven hundred and sixtyfour',
#   'pm',
#   'payafter',
#   'tax',
#   'deduction',
#   'pls',
#   'advice',
#   'tentative',
#   'monthly',
#   'expenses',
#   'couple',
#   'saving',
#   'possible'],
#  ['stereotypes', 'united', 'kingdom'],
#  ['use', 'twitter', 'business', 'source'],
#  ['transfer', 'money', 'skrill', 'paypal', 'account'],
#  ['best', 'earphone', 'deep', 'bass', 'one thousand'],
#  ['government', 'employees', 'eligible', 'sukanya', 'samrudi', 'yojana'],
#  ['correct', 'looking', 'forward', 'speak', 'look', 'forward', 'speak'],
#  ['best', 'engineering', 'fields'],
#  ['make',
#   'life',
#   'suit',
#   'stop',
#   'life',
#   'abusing',
#   'mentally',
#   'emotionally'],
#  ['difference', 'gross', 'salary', 'ctc'],
#  ['prospering', 'towns', 'kerala'],
#  ['best', 'way', 'gain', 'confidence'],
#  ['anyone', 'see', 'relation', 'greek', 'gods', 'hindu', 'gods'],
#  ['switch', 'apple', 'music', 'spotify'],
#  ['best', 'fixed', 'income', 'fund'],
#  ['like', 'live', 'cologne'],
#  ['robert', 'de', 'niro', 'al', 'pacino', 'successful'],
#  ['people', 'prefer', 'small', 'families'],
#  ['animals', 'kiss'],
#  ['get', 'deleted', 'instagram', 'chats'],
#  ['stop', 'addicted', 'love'],
#  ['hired', 'two', 'private', 'eyes', 'ordered', 'follow'],
#  ['find', 'startup', 'accelerator'],
#  ['check', 'wifi', 'history', 'access', 'android', 'phones'],
#  ['significance',
#   'battle',
#   'somme',
#   'battle',
#   'compare',
#   'contrast',
#   'battle',
#   'rostov'],
#  ['creative', 'college', 'admissions', 'essay', 'read'],
#  ['would',
#   'happen',
#   'cover',
#   'one',
#   'eyes',
#   'eye',
#   'patch',
#   'one',
#   'year',
#   'take',
#   'patch'],
#  ['possible', 'pursue', 'many', 'different', 'things', 'life'],
#  ['ben', 'affleck', 'shine', 'christian', 'bale', 'batman'],
#  ['business', 'good', 'start', 'hyderabad'],
#  ['stop', 'possessive'],
#  ['wife', 'lord', 'krishna'],
#  ['best',
#   'combination',
#   'courses',
#   'take',
#   'along',
#   'ca',
#   'enhance',
#   'career'],
#  ['take', 'screenshot', 'mac', 'laptop'],
#  ['work', 'executive', 'recruiter', 'like'],
#  ['psychological', 'need', 'collecting', 'fulfill'],
#  ['must', 'watch', 'tv', 'shows', 'die'],
#  ['become', 'fluent', 'chinese'],
#  ['effects',
#   'demonitization',
#   'five hundred',
#   'one thousand',
#   'rupees',
#   'notes',
#   'real',
#   'estate',
#   'sector'],
#  ['easiest', 'way', 'become', 'billionaire'],
#  ['people',
#   'willing',
#   'give',
#   'free',
#   'lectures',
#   'conduct',
#   'free',
#   'workshop',
#   'india',
#   'colleges'],
#  ['best', 'way', 'start', 'learning', 'robotics'],
#  ['people', 'hate', 'hillary', 'clinton'],
#  ['women',
#   'periods',
#   'regarded',
#   'unclean',
#   'prevented',
#   'taking',
#   'actived',
#   'part',
#   'rituals',
#   'hinduism'],
#  ['atheism', 'lack', 'belief', 'gods', 'term', 'belief', 'god'],
#  ['like', 'jack', 'dorsey'],
#  ['best', 'quoteslessons', 'assassin', 'creed', 'series'],
#  ['inkjet',
#   'printers',
#   'use',
#   'color',
#   'ink',
#   'printing',
#   'black',
#   'white',
#   'documents'],
#  ['creativity', 'important'],
#  ['hillary',
#   'clinton',
#   'could',
#   'continue',
#   'presidential',
#   'campaign',
#   'would',
#   'democratic',
#   'party',
#   'choose',
#   'new',
#   'candidate'],
#  ['headphones',
#   'work',
#   'antenna',
#   'play',
#   'fm',
#   'radio',
#   'channels',
#   'mobile',
#   'phones',
#   'mobile',
#   'companies',
#   'install',
#   'inbuilt',
#   'antenna',
#   'phones',
#   'able',
#   'play',
#   'fm',
#   'without',
#   'headphones'],
#  ['best',
#   'career',
#   'growth',
#   'technologies',
#   'automation',
#   'engineers',
#   'apart',
#   'automation',
#   'tools'],
#  ['disadvantages', 'listing', 'company', 'nse'],
#  ['many',
#   'derivatives',
#   'object',
#   'position',
#   'respect',
#   'time',
#   'continuous'],
#  ['neutron', 'star', 'made'],
#  ['got',
#   'thirtyeight',
#   'gpa',
#   'enough',
#   'get',
#   'top',
#   'universities',
#   'like',
#   'harvard'],
#  ['profitable', 'way', 'trade', 'binary', 'options'],
#  ['utilize', 'free', 'time', 'avoid', 'depression'],
#  ['learn', 'computer', 'security'],
#  ['earn', 'quora'],
#  ['puk', 'code'],
#  ['find', 'job', 'japan'],
#  ['examples', 'sentences', 'using', 'word', 'hysteria'],
#  ['another', 'billion', 'dollar', 'lottery', 'jackpot'],
#  ['scary', 'drive', 'road', 'hana', 'given', 'turns'],
#  ['create',
#   'new',
#   'new',
#   'terminal',
#   'using',
#   'c',
#   'programming',
#   'linux',
#   'terminal'],
#  ['cognition', 'affect', 'perception'],
#  ['tqwl', 'different', 'ckwl', 'tatkal', 'waiting', 'list'],
#  ['make', 'world', 'better', 'place', 'live', 'future', 'generations'],
#  ['many', 'champions', 'league', 'legends'],
#  ['drinking', 'four', 'liters', 'water', 'day', 'unhealthy'],
#  ['water',
#   'great',
#   'lakes',
#   'come',
#   'lakes',
#   'wildlife',
#   'compare',
#   'lake',
#   'prespa'],
#  ['porn', 'stars', 'watch', 'porn'],
#  ['trump', 'supporters', 'feel', 'way', 'walking', 'back', 'promises'],
#  ['worried', 'others', 'opinions'],
#  ['potty', 'train', 'four', 'months', 'pitbull'],
#  ['jump', 'rope', 'five', 'minutes', 'many', 'calories', 'use'],
#  ['online',
#   'test',
#   'series',
#   'best',
#   'gate',
#   'two thousand and seventeen',
#   'cs',
#   'stream'],
#  ['best', 'material', 'understanding', 'algorithmic', 'analysis', 'newbie'],
#  ['temperament', 'bullmastiffhusky', 'mix'],
#  ['eight',
#   'balls',
#   'seven',
#   'weigh',
#   'one',
#   'different',
#   'weight',
#   'know',
#   'heavier',
#   'lighter',
#   'find',
#   'odd',
#   'ball',
#   'two',
#   'weighs'],
#  ['play', 'raisin', 'sun', 'walter', 'ad', 'beneatha', 'argue'],
#  ['signs', 'ultra', 'smart', 'person', 'playing', 'dumb'],
#  ['dark', 'energy', 'created', 'expansion', 'infinite', 'created'],
#  ['get', 'book', 'published'],
#  ['disrupting', 'bloomberg'],
#  ['flash', 'run', 'fast'],
#  ['best',
#   'way',
#   'invest',
#   'five hundred',
#   'legally',
#   'get',
#   'tangible',
#   'profits',
#   'relatively',
#   'short',
#   'period',
#   'time',
#   'say',
#   'six',
#   'months'],
#  ['implementation', 'gst', 'bill', 'impact', 'lives', 'common', 'people'],
#  ['recover', 'gmail', 'password'],
#  ['accurately', 'mental', 'illness', 'diagnosed'],
#  ['knee', 'pain', 'twenty', 'year', 'old', 'girl', 'normal'],
#  ['qualities', 'good', 'leader'],
#  ['difference', 'bay', 'gulf', 'straits'],
#  ['modi', 'win', 'two thousand and nineteen'],
#  ['open', 'dmart', 'store', 'india', 'franchise'],
#  ['best', 'youtube', 'channels', 'learn', 'medicine'],
#  ['swami',
#   'vivekananda',
#   'ever',
#   'eat',
#   'nonveg',
#   'egg',
#   'journey',
#   'around',
#   'world'],
#  ['happen', 'cancel', 'tqwl', 'tickets', 'charting', 'done'],
#  ['exactly', 'common', 'core', 'initiativestandards', 'pros', 'cons'],
#  ['choose', 'journal', 'publish', 'paper'],
#  ['new', 'year', 'resolutions', 'two thousand and seventeen'],
#  ['bad', 'dream'],
#  ['slavs', 'squat'],
#  ['many', 'marks', 'score', 'aiims', 'rank', 'one hundred and fiftyone'],
#  ['operating',
#   'room',
#   'two',
#   'surgeons',
#   'equal',
#   'experience',
#   'disagree',
#   'surgical',
#   'procedure',
#   'tie',
#   'broken'],
#  ['many',
#   'months',
#   'take',
#   'gain',
#   'knowledge',
#   'developing',
#   'android',
#   'apps',
#   'scratch'],
#  ['love', 'body', 'guy'],
#  ['rights', 'prisoner'],
#  ['get', 'free', 'gems', 'clash', 'clans'],
#  ['apps', 'like', 'word', 'lens'],
#  ['exgirlfriend',
#   'suffering',
#   'malaria',
#   'deep',
#   'urge',
#   'visiting',
#   'placements',
#   'idea'],
#  ['best', 'way', 'get', 'traffic', 'website'],
#  ['feel', 'someone', 'upvotes', 'answer', 'quora'],
#  ['best',
#   'films',
#   'tv',
#   'shows',
#   'feature',
#   'strong',
#   'female',
#   'protagonists'],
#  ['far', 'would', 'go', 'love', 'wait', 'one', 'love', 'ir', 'move'],
#  ['people', 'die'],
#  ['clothes', 'made', 'polyester', 'instead', 'cotton'],
#  ['bone', 'marrow'],
#  ['slave', 'name', 'reddice'],
#  ['long', 'take', 'dead', 'body', 'float', 'surface', 'drowning'],
#  ['get', 'friend', 'talked', 'three', 'years', 'still', 'miss'],
#  ['travelling',
#   'new',
#   'region',
#   'better',
#   'immerse',
#   'twelve',
#   'cities',
#   'see',
#   'many',
#   'cities',
#   'cram'],
#  ['make', 'money', 'online', 'free', 'cost'],
#  ['buy', 'best', 'quality', 'customized', 'cupcakes', 'gold', 'coast'],
#  ['successful', 'odd', 'even', 'plan'],
#  ['war', 'india', 'pakistan', 'win'],
#  ['deal', 'fear', 'dying'],
#  ['would',
#   'estimated',
#   'cost',
#   'repairing',
#   'cracked',
#   'screen',
#   'iphone',
#   'six'],
#  ['interesting',
#   'products',
#   'innovations',
#   'mcdonald',
#   'coming',
#   'two thousand and sixteen'],
#  ['end', 'universe', 'universe', 'infinite'],
#  ['cpagripcom'],
#  ['much', 'funds', 'raise'],
#  ['anna', 'hazare', 'think', 'pm', 'modi'],
#  ['effect',
#   'banning',
#   'five hundred',
#   'one thousand',
#   'notes',
#   'stock',
#   'markets',
#   'india'],
#  ['concentric', 'contractions', 'differ', 'eccentric', 'contractions'],
#  ['puppet', 'used', 'yoda', 'episode', 'suck', 'bad'],
#  ['online', 'platforms', 'post', 'ads', 'beer', 'money', 'opportunity'],
#  ['meaning', 'life'],
#  ['start', 'small', 'business', 'effectively'],
#  ['acquire', 'positive', 'morality'],
#  ['need', 'friends'],
#  ['exist'],
#  ['best', 'hollywood', 'thriller', 'movies'],
#  ['repeat',
#   '2nd',
#   'year',
#   'college',
#   'find',
#   'new',
#   'college',
#   'five',
#   'year',
#   'course'],
#  ['petrol',
#   'diesel',
#   'pumped',
#   'filling',
#   'station',
#   'using',
#   'motor',
#   'without',
#   'igniting',
#   'fire'],
#  ['job', 'possibilities', 'exist', 'bachelors', 'homeland', 'security'],
#  ['best', 'books', 'understand', 'calculus'],
#  ['break', 'herhim'],
#  ['use', 'jio', 'sim', 'iphone', '5s'],
#  ['unwritten', 'rules', 'usa'],
#  ['best', 'answer', 'two', 'years', 'gap', 'job', 'interview'],
#  ['best', 'songs', 'low', 'voices'],
#  ['anyone', 'predict', 'birth', 'chart'],
#  ['birth', 'trigonometric', 'functions'],
#  ['saying',
#   'mean',
#   'trust',
#   'everything',
#   'see',
#   'even',
#   'salt',
#   'looks',
#   'like',
#   'sugar'],
#  ['countries', 'prevent', 'war'],
#  ['become', 'billionaire'],
#  ['learn', 'web', 'design'],
#  ['best',
#   'online',
#   'calenderschedulingbooking',
#   'system',
#   'something',
#   'allows',
#   'show',
#   'availability',
#   'customers',
#   'arequest',
#   'meet',
#   'accept',
#   'request',
#   'appointment',
#   'pops',
#   'calendars',
#   'reminders',
#   'automated'],
#  ['indian',
#   'gdp',
#   'affected',
#   'banning',
#   'five hundred',
#   'one thousand',
#   'rupees',
#   'notes'],
#  ['understanding', 'death', 'philosophical'],
#  ['dogs', 'considered', 'omnivores'],
#  ['like', 'cheated', 'upon', 'relationship'],
#  ['know', 'someone', 'blocked', 'texts'],
#  ['interesting', 'foods', 'eaten', 'country'],
#  ['like', 'private', 'banker'],
#  ['journalism'],
#  ['one', 'increase', 'concentration'],
#  ['see', 'sent', 'invitations', 'linkedin', 'pending', 'invitations'],
#  ['pros', 'cons', 'german', 'shepherd', 'dog'],
#  ['difference', 'deism', 'agnosticism'],
#  ['male', 'porn', 'stars', 'masturbate', 'ejaculate'],
#  ['much',
#   'cgpa',
#   'require',
#   'get',
#   'admission',
#   'mtech',
#   'cse',
#   'iit',
#   'madras'],
#  ['biological', 'reason', 'people', 'cry', 'emotional'],
#  ['five', 'facts', 'earth', 'crust'],
#  ['isro', 'use', 'friction', 'stir', 'welding', 'technology'],
#  ['wish',
#   'simulate',
#   'fake',
#   'location',
#   'app',
#   'running',
#   'ios',
#   'device',
#   'fake',
#   'gps',
#   'location',
#   'ios',
#   'without',
#   'jailbreaking',
#   'noncoder'],
#  ['would', 'best', 'way', 'quit', 'smoking'],
#  ['best', 'programing', 'language', 'tcs'],
#  ['earthquake', 'resistant', 'homes'],
#  ['kristen', 'stewart', 'bad', 'actress'],
#  ['japanese', 'guys', 'try', 'look', 'feminine', 'girls', 'find', 'gross'],
#  ['five', 'popular', 'sugar', 'daddy', 'websites'],
#  ['vtu',
#   '1st',
#   'sem',
#   'exam',
#   'time',
#   'table',
#   'two thousand and sixteen',
#   'dec'],
#  ['best', 'phone', 'buy', '15k'],
#  ['start', 'business'],
#  ['best', 'neardeath', 'experience', 'ever'],
#  ['keep', 'getting', 'fleas', 'dogs'],
#  ['year', 'letter', 'j', 'come'],
#  ['harvard',
#   'college',
#   'courses',
#   'general',
#   'shopping',
#   'advice',
#   'turkish',
#   'classes'],
#  ['send',
#   'message',
#   'one',
#   'android',
#   'phone',
#   'another',
#   'android',
#   'phone',
#   'bluetooth'],
#  ['important', 'books', 'ever', 'written'],
#  ['universities',
#   'sigma',
#   'designs',
#   'recruit',
#   'new',
#   'grads',
#   'majors',
#   'looking'],
#  ['mphil', 'india', 'masters', 'uk', 'psychology'],
#  ['universities',
#   'powell',
#   'industries',
#   'recruit',
#   'new',
#   'grads',
#   'majors',
#   'looking'],
#  ['best', 'movie', 'posters', 'come', 'across'],
#  ['examples', 'deuteromycota', 'formed'],
#  ['racist', 'racist'],
#  ['differences', 'however', 'nevertheless'],
#  ['canada', 'geese', 'really', 'canadian'],
#  ['find',
#   'zeros',
#   'polynomial',
#   'function',
#   'math',
#   'f',
#   'x',
#   'dfrac',
#   'one',
#   'two',
#   'x',
#   'three',
#   '3x',
#   'math'],
#  ['edit', 'devices', 'google', 'play', 'account'],
#  ['become', 'good', 'speaker'],
#  ['write', 'letter', 'mr', 'narendra', 'modi'],
#  ['electable',
#   'general',
#   'presidential',
#   'election',
#   'donald',
#   'trump',
#   'ted',
#   'cruz'],
#  ['name', 'bastards', 'snow'],
#  ['think', 'bermuda', 'triangle'],
#  ['mexican', 'girls', 'like', 'black', 'guys'],
#  ['lived', 'tiny', 'house'],
#  ['boygirl',
#   'called',
#   'heshe',
#   'sixteen',
#   'years',
#   'old',
#   '611years',
#   'old',
#   'one thousand one hundred and fourteen',
#   'years',
#   'old',
#   'one thousand four hundred and eighteen',
#   'years',
#   'old'],
#  ['debeak', 'cockerels', 'eight', 'months', 'old'],
#  ['someone', 'overcome', 'anxiety'],
#  ['avoid', 'whey', 'yogurt'],
#  ['love',
#   'bisexual',
#   'best',
#   'friend',
#   'also',
#   'guy',
#   'girlfriend',
#   'want',
#   'tell',
#   'move'],
#  ['best', 'university', 'germany', 'ms'],
#  ['maintain', 'peace', 'mind'],
#  ['car', 'good', 'build', 'quality', 'india'],
#  ['massaging', 'one', 'temples', 'soothe', 'migraine', 'headache'],
#  ['one', 'better', 'among', 'kmc', 'manipal', 'kmc', 'mangalore'],
#  ['bestfriend', 'still', 'ignoring'],
#  ['sensors',
#   'available',
#   'acer',
#   'liquid',
#   'z630s',
#   'android',
#   'smart',
#   'phone',
#   'using',
#   'cpuz',
#   'app'],
#  ['keep', 'motivation', 'learn', 'language'],
#  ['top', 'assessment', 'companies', 'india'],
#  ['mean', 'emoticon'],
#  ['pinkish', 'discharge', 'normal', 'early', 'pregnancy', 'causes'],
#  ['best', 'ways', 'properly', 'finger'],
#  ['scientists', 'work'],
#  ['many', 'sponsored', 'candidates', 'shortlisted', 'cmc', 'vellore'],
#  ['different',
#   'chinese',
#   'wedding',
#   'ceremony',
#   'western',
#   'wedding',
#   'ceremony'],
#  ['condition', 'tourism', 'pakistan'],
#  ['different', 'offshore', 'onshore', 'funds'],
#  ['one', 'hate', 'shahrukh', 'khan'],
#  ['best', 'selfhelp', 'books', 'ever', 'read'],
#  ['evernote', 'useful'],
#  ['title', 'continuation', 'gift', 'magi'],
#  ['good', 'song', 'lyric', 'prank', 'best', 'friend'],
#  ['argued',
#   'gf',
#   'made',
#   'friends',
#   'person',
#   'hit',
#   'said',
#   'control',
#   'freak',
#   'wants',
#   'freedom'],
#  ['pass', 'drug', 'test', 'methamphetamine'],
#  ['could', 'start', 'open', 'source', 'development'],
#  ['dreams', 'look', 'real'],
#  ['cricket', 'players', 'really', 'drink', 'tea', 'tea', 'break'],
#  ['get', 'entry', 'mit'],
#  ['fetus', 'breathe', 'inside', 'womb'],
#  ['movies', 'incest', 'scenes'],
#  ['signs', 'guy', 'feelings', 'crush', 'want', 'show', 'hides'],
#  ['according',
#   'international',
#   'federation',
#   'robotics',
#   'many',
#   'robots',
#   'existed',
#   'two thousand and twelve'],
#  ['oberon', 'mad', 'titania', 'midsummer', 'night', 'dream'],
#  ['regret', 'divorce'],
#  ['much',
#   'dna',
#   'change',
#   'time',
#   'clone',
#   'seventy',
#   'years',
#   'clone',
#   'hair',
#   'color'],
#  ['right', 'tell', 'girl', 'feelings'],
#  ['donald', 'trump', 'taking', 'cocaine', 'howard', 'dean', 'suggests'],
#  ['true',
#   'order',
#   'part',
#   'elite',
#   'rich',
#   'successful',
#   'join',
#   'secret',
#   'organisation',
#   'otherwise',
#   'chance'],
#  ['financially', 'beneficial', 'firm', 'teaching', 'architecture', 'college'],
#  ['see', 'comedy', 'nights', 'kapil', 'live', 'show'],
#  ['sandeep', 'maheshwari', 'quora'],
#  ['biggest', 'monster', 'monster', 'hunter'],
#  ['convince', 'people', 'stop', 'blaspheming', 'holy', 'spirit'],
#  ['stop', 'watching', 'porn'],
#  ['start', 'trusting', 'one'],
#  ['bucket', 'list'],
#  ['first', 'come', 'across', 'porn'],
#  ['car',
#   'services',
#   'available',
#   'normal',
#   'il',
#   'good',
#   'compared',
#   'taxis',
#   'relative'],
#  ['charged', 'molecules', 'pass', 'lipid', 'cell', 'membrane'],
#  ['feel', 'spouse', 'renowned', 'porn', 'star'],
#  ['best', 'hostel', 'booking', 'affiliate', 'program'],
#  ['drive',
#   'brooklyn',
#   'staten',
#   'island',
#   'described',
#   'cities',
#   'tourist',
#   'attractions',
#   'compare',
#   'queens'],
#  ['eat', 'every', 'day', 'healthy'],
#  ['make', 'free', 'calls', 'family', 'members', 'airtel', 'andhra', 'pradesh'],
#  ['would', 'hillary', 'clinton', 'election'],
#  ['use', 'vicks', 'vapor', 'rub', 'stuffy', 'nose'],
#  ['start',
#   'prepare',
#   'ugc',
#   'net',
#   'english',
#   'literature',
#   'latest',
#   'syllabus'],
#  ['early', 'europeans', 'get', 'protein', 'columbian', 'exchange'],
#  ['best', 'forum', 'graphic', 'designers'],
#  ['alex', 'jones', 'satirical', 'show'],
#  ['learn',
#   'angularjs',
#   'fifteen',
#   'instead',
#   'angularjs',
#   'two',
#   'know',
#   'typescript'],
#  ['fall', 'asleep', 'days'],
#  ['marvel', 'movies', 'included', 'stan', 'lee', 'cameos'],
#  ['views',
#   'modi',
#   'governments',
#   'decision',
#   'demonetize',
#   'five hundred',
#   'one thousand',
#   'rupee',
#   'notes',
#   'affect',
#   'economy'],
#  ['one hundred and six', 'label', 'mad', 'hatter', 'hat', 'mean'],
#  ['wrote', 'kars', 'kids', 'jingle'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'greece'],
#  ['minimum', 'requirements', 'enter', 'mit'],
#  ['answer', 'question', 'quora'],
#  ['israel', 'vs', 'iran', 'would', 'win'],
#  ['late', 'learn', 'piano'],
#  ['natural', 'numbers'],
#  ['one', 'plus', '3t', '4g', 'volte', 'enabled', 'phone'],
#  ['enter', 'new', 'email', 'id', 'access', 'recover', 'facebook', 'id'],
#  ['travel', 'faster', 'light'],
#  ['like', 'firefighter'],
#  ['factors',
#   'causes',
#   'data',
#   'inconsistency',
#   'distributed',
#   'platformapplication'],
#  ['differences', 'pocso', 'sexual', 'offenses', 'ipc'],
#  ['alternative', 'word'],
#  ['considered', 'illegal', 'screen', 'nba'],
#  ['nothing', 'excites', 'anymore', 'regain', 'excitement'],
#  ['life', 'lessons', 'batman', 'teaches', 'us'],
#  ['stop', 'criminal', 'attempt', 'kidnap', 'escape', 'unharmed'],
#  ['sell', 'amazon'],
#  ['daniel', 'ek', 'expect', 'spotify', 'india'],
#  ['top', 'ten', 'books', 'one', 'read', 'early', '20s'],
#  ['book', 'start', 'gate', 'preparation'],
#  ['phrase', 'love', 'abides', 'death', 'exactly', 'mean'],
#  ['similar', '4shared'],
#  ['get',
#   'high',
#   'someone',
#   'touches',
#   'weed',
#   'shake',
#   'hand',
#   'eat',
#   'something',
#   'hand'],
#  ['considering',
#   'current',
#   'trend',
#   'information',
#   'technology',
#   'future',
#   'print',
#   'media'],
#  ['best', 'recipe', 'chicken', 'pizza'],
#  ['good', 'places', 'learn', 'mountaineering', 'india'],
#  ['new', 'table', 'tennis', 'balls', 'damage', 'rubbers'],
#  ['new', 'xbox', 'one', 'connect', 'internet', 'setup', 'solutions'],
#  ['wrong', 'content', 'life'],
#  ['gravity', 'theory'],
#  ['could', 'become', 'fighter', 'pilot', 'less', 'required', 'eyesight'],
#  ['operation', 'executive', 'salary', 'infosys'],
#  ['cavemen', 'scientifically', 'tested'],
#  ['climate', 'change', 'reversed'],
#  ['ask', 'crush', 'number'],
#  ['believe', 'gravitation', 'force', 'exist'],
#  ['mahabharata', 'really', 'happen'],
#  ['congress', 'stop', 'presidents', 'starting', 'major', 'war'],
#  ['safe', 'lose', 'twentyfive', 'pounds', 'one', 'month'],
#  ['cute', 'shounen', 'ai', 'series'],
#  ['police', 'lights', 'red', 'blue'],
#  ['post', 'question', 'marked', 'needing', 'improvement'],
#  ['owns', 'nature'],
#  ['install', 'obbdata', 'file', 'android'],
#  ['garbage', 'value', 'get', 'garbage', 'value', 'c'],
#  ['prepare', 'software', 'interviews'],
#  ['rahul', 'gandhi', 'chance', 'become', 'next', 'pm', 'india', 'modi'],
#  ['noon', 'twelve', 'twelve', 'pm'],
#  ['difference', 'comet', 'asteroid'],
#  ['chocolate', 'milk', 'good'],
#  ['study'],
#  ['country', 'best', 'higher', 'education', 'work'],
#  ['painting', 'image'],
#  ['major',
#   'highways',
#   'california',
#   'compared',
#   'major',
#   'highways',
#   'tennessee'],
#  ['beyond', 'universe'],
#  ['growing', 'hair', 'physical', 'chemical', 'change'],
#  ['difference', 'culture', 'history'],
#  ['mean', 'guy', 'says', 'like'],
#  ['makes', 'programmer', 'good'],
#  ['likely', 'world', 'war', 'iii'],
#  ['civil', 'war', 'likely', 'us', 'presidential', 'election'],
#  ['european', 'country', 'best', 'asylum', 'seekers'],
#  ['crop', 'circles', 'get', 'generated'],
#  ['baking', 'soda', 'help', 'pass', 'urine', 'test'],
#  ['zika', 'virus', 'transmitted'],
#  ['best', 'way', 'learn', 'algebra'],
#  ['feel', 'retake', 'class', 'college'],
#  ['google',
#   'display',
#   'network',
#   'require',
#   'site',
#   'seo',
#   'onpage',
#   'offpage',
#   'optimized',
#   'first',
#   'proceed',
#   'gdn',
#   'possible'],
#  ['hard', 'fake', 'appearing', 'spiritual', 'christian', 'community'],
#  ['actinomorphic', 'flower'],
#  ['best', 'place', 'sex'],
#  ['people', 'anemia', 'die', 'younger'],
#  ['feel', 'new', 'macbook', 'pro', 'late', 'two thousand and sixteen'],
#  ['covering', 'head', 'sleeping', 'brain', 'damage'],
#  ['major', 'differences', 'chinese', 'culture', 'western', 'cultures'],
#  ['scraping', 'techniques'],
#  ['29y',
#   'old',
#   'diabetic',
#   'type',
#   'two',
#   'recently',
#   'sugar',
#   'level',
#   'increased',
#   'one hundred and fifty',
#   'fasting',
#   'exercise',
#   'eat',
#   'whole',
#   'grains',
#   'happening'],
#  ['healthy', 'eat', 'egg', 'whites', 'every', 'day'],
#  ['words', 'rank', 'highest', 'dictionarycom', 'difficulty', 'index'],
#  ['feel', 'remorse', 'empathy'],
#  ['many', 'minutes', 'cardio', 'day'],
#  ['dog', 'biting'],
#  ['treat', 'severe', 'foot', 'sprain'],
#  ['severe', 'crick', 'neck', 'treated'],
#  ['best', 'places', 'recommend', 'foreigners', 'visit', 'nepal'],
#  ['activate',
#   'dlc',
#   'skyrim',
#   'laptop',
#   'got',
#   'working',
#   'computer',
#   'command',
#   'lines',
#   'laptop',
#   'use'],
#  ['prepare', 'hsbc', 'glt', 'placement', 'tests'],
#  ['indian', 'writersauthors', 'ever', 'use', 'pen', 'name'],
#  ['register',
#   'institute',
#   'providing',
#   'training',
#   'various',
#   'programming',
#   'languages',
#   'vocational',
#   'courses',
#   'exempt',
#   'service',
#   'tax'],
#  ['imminent', 'world', 'war', 'iii'],
#  ['write', 'song'],
#  ['could', 'narendra', 'modi', 'next', 'move', 'demonetization'],
#  ['want', 'share', 'share', 'got'],
#  ['interesting', 'fact', 'know'],
#  ['problem', 'controlled', 'fusion'],
#  ['find', '3ds', 'emulator', 'android'],
#  ['want',
#   'start',
#   'clothes',
#   'boutique',
#   'india',
#   'buy',
#   'cheap',
#   'wholesale',
#   'clothes'],
#  ['become', 'true', 'computer', 'science', 'engineer'],
#  ['necessary', 'unlock', 'bootloader', 'rooting', 'android', 'phones'],
#  ['bss', 'engineer'],
#  ['get',
#   'punished',
#   'quora',
#   'moderators',
#   'put',
#   'israel',
#   'judaism',
#   'negative',
#   'light'],
#  ['lucid', 'dreams'],
#  ['feel', 'like', 'beautiful'],
#  ['possible', 'ca', '12th', 'science'],
#  ['hack', 'someones', 'whatsapp', 'account'],
#  ['like', 'study', 'math', 'ucla'],
#  ['best', 'lesson', 'life'],
#  ['interesting', 'mobile', 'apps'],
#  ['trump',
#   'presidency',
#   'affect',
#   'indian',
#   'students',
#   'planning',
#   'phd',
#   'us'],
#  ['various', 'batman', 'movies', 'series', 'order'],
#  ['best', 'daily', 'life', 'hacks', 'one', 'use', 'make', 'life', 'easy'],
#  ['much', 'weight', 'lose', 'eating', 'week'],
#  ['favourite', 'anime', 'character'],
#  ['atm', 'machines', 'work', 'internally'],
#  ['many', 'mechanical', 'engineers', 'graduate', 'india', 'per', 'year'],
#  ['start', 'successful', 'private', 'equity', 'firm'],
#  ['underrated', 'date', 'activities'],
#  ['common', 'facts', 'every', 'mechanical', 'engineer', 'know'],
#  ['medium',
#   'budget',
#   'visit',
#   'best',
#   'places',
#   'kerala',
#   'three',
#   'members',
#   'twentythree',
#   'days'],
#  ['quora', 'digest', 'filled', 'questions', 'google', 'iq', 'china'],
#  ['would', 'destroy', 'world'],
#  ['earn', 'money', 'youtube'],
#  ['differences', 'particles', 'molecules'],
#  ['facebook', 'add', 'mutual', 'friends'],
#  ['russian',
#   'president',
#   'vladmir',
#   'putin',
#   'like',
#   'person',
#   'closest',
#   'friends',
#   'family'],
#  ['start', 'writing'],
#  ['time',
#   'started',
#   'big',
#   'bang',
#   'happening',
#   'could',
#   'big',
#   'bang',
#   'start',
#   'time',
#   'big',
#   'bang',
#   'start'],
#  ['feel', 'relationship', 'single', 'life', 'changes', 'relationship'],
#  ['start', 'civil', 'service', 'exam', 'preparation', 'scratch'],
#  ['noninvasive', 'blood', 'glucose', 'monitoring', 'systems', 'abroad'],
#  ['difference', 'pleasure', 'masturbation', 'sex'],
#  ['things', 'change', 'stay', 'mean'],
#  ['start', 'solar', 'energy', 'business', 'egypt'],
#  ['pc',
#   'specs',
#   'two',
#   'gb',
#   'ddr2',
#   'ram',
#   'intel',
#   'core',
#   'duo',
#   'thirtyfive',
#   'ghz',
#   'nvidia',
#   'geforce',
#   'gt',
#   'six hundred and ten',
#   '3gb',
#   'ddr3',
#   'run',
#   'assassin',
#   'creed',
#   'syndicate',
#   'gta',
#   'v'],
#  ['psychic', 'abilities'],
#  ['manage', 'time', 'studies'],
#  ['academic', 'calendar', 'xlri'],
#  ['take', 'urjit', 'patel', 'new', 'rbi', 'governor'],
#  ['want', 'president'],
#  ['india', 'friendly', 'relations', 'neighbouring', 'countries'],
#  ['trump', 'voters', 'care', 'reneged', 'campaign', 'promises'],
#  ['learn', 'sleeping'],
#  ['play', 'asian', 'playstation', 'four', 'games', 'european', 'playstation'],
#  ['stop', 'addicted', 'porn'],
#  ['british',
#   'engineering',
#   'manufacturing',
#   'skills',
#   'decline',
#   'dramatically',
#   '60s',
#   '70s',
#   '80s',
#   'especially',
#   'compared',
#   'germany'],
#  ['work', 'machine', 'learning', 'researchers', 'graduation'],
#  ['future', 'ios', 'developers'],
#  ['meaning', 'life', 'purpose', 'earth'],
#  ['boyfriend'],
#  ['time', 'travel', 'possible'],
#  ['one', 'get', 'fuller', 'face'],
#  ['late', 'age', 'twentyfive', 'thinking', 'start', 'career', 'photography'],
#  ['best', 'time', 'sex'],
#  ['weld', 'steel', 'aluminum', 'together'],
#  ['youtube', 'video', 'highest', 'likedislike', 'ratio'],
#  ['solution', 'kashmir', 'issue'],
#  ['dug', 'hole', 'earth', 'came', 'side', 'would', 'happen'],
#  ['create', 'free', 'energy'],
#  ['web', 'design'],
#  ['funniest', 'highbrow', 'joke', 'ever', 'heard'],
#  ['find', 'phenotypic', 'ratio'],
#  ['saturn', 'benefit', 'house', 'sits', 'slowly'],
#  ['academically', 'qualified', 'bollywood', 'celebrity'],
#  ['difference', 'quality', 'wired', 'wireless', 'headphones'],
#  ['movies', 'everyone', 'needs', 'watch', 'least', 'life'],
#  ['world', 'war', 'three', 'ever', 'take', 'place'],
#  ['eating', 'prunes', 'help', 'constipation'],
#  ['given',
#   'statement',
#   'correct',
#   'unccd',
#   'question',
#   'cse',
#   'prelim',
#   'two thousand and sixteen',
#   'many',
#   'coachings',
#   'taken',
#   '2nd',
#   'statement',
#   'wrong'],
#  ['would',
#   'today',
#   'technology',
#   'never',
#   'realized',
#   'value',
#   'binary',
#   'numbers',
#   'harnessed',
#   'produce',
#   'digital',
#   'technology'],
#  ['best', 'way', 'invest', 'oil', 'natural', 'gas'],
#  ['arnab', 'goswami', 'probjp'],
#  ['good', 'sources', 'learning', 'nuget'],
#  ['would', 'describe', 'person', 'lots', 'interests'],
#  ['possible', 'turn', 'indicator', 'light', 'dahua', 'camera'],
#  ['barack', 'obama', 'important', 'world'],
#  ['reason', 'pakistan', 'supports', 'terrorism'],
#  ['stop', 'hairfall'],
#  ['opinion', 'best', 'classical', 'song', 'time'],
#  ['unusual', 'aspects', 'politics', 'government', 'hungary'],
#  ['aim'],
#  ['respond', 'boss', 'fired', 'via', 'email'],
#  ['cheap', 'budget', 'stay', 'options', 'north', 'goa'],
#  ['website', 'similar', 'quora'],
#  ['conditions', 'european', 'refugee', 'camps'],
#  ['opposite', 'homebird'],
#  ['know', 'fiance', 'loves'],
#  ['somebody', 'explain', 'problem', 'steps'],
#  ['develop', 'presence', 'mind'],
#  ['mathematical', 'fallacies', 'wrong', 'proof', 'twentytwo', 'five'],
#  ['help', 'cibil', 'score', 'pay', 'writtenoff', 'amount'],
#  ['hobbit', 'considered', 'canonical', 'tolkien', 'work'],
#  ['japanese', 'think', 'malaysian'],
#  ['har', 'ki', 'dun', 'trek', 'easy'],
#  ['good', 'websites', 'learn', 'c', 'programming', 'begineer'],
#  ['supreme',
#   'court',
#   'decision',
#   'playing',
#   'national',
#   'anthem',
#   'movie',
#   'screenings',
#   'affect',
#   'patriotism'],
#  ['united',
#   'states',
#   'female',
#   'president',
#   'husband',
#   'called',
#   'first',
#   'gentleman',
#   'bill',
#   'clinton',
#   'called',
#   'hillary',
#   'elected'],
#  ['get',
#   'moocelearning',
#   'online',
#   'web',
#   'video',
#   'courses',
#   'related',
#   'filmmaking',
#   'production',
#   'developed',
#   'indian',
#   'professors'],
#  ['mobile',
#   'number',
#   'portability',
#   'finally',
#   'start',
#   'may',
#   'three',
#   'network',
#   'providers',
#   'really',
#   'agree'],
#  ['people', 'hate', 'twilight', 'saga'],
#  ['believe',
#   'imperialism',
#   'left',
#   'positive',
#   'negative',
#   'legacy',
#   'indian',
#   'subcontinent',
#   'africa'],
#  ['c', 'best', 'programming', 'language'],
#  ['improve', 'spoken', 'english', 'ability'],
#  ['gay', 'sex'],
#  ['transferring',
#   'school',
#   'us',
#   'curriculum',
#   'taking',
#   'ibdp',
#   'philippine',
#   'school',
#   'w',
#   'percent',
#   'average',
#   'grading',
#   'system',
#   'get',
#   'gpa'],
#  ['make', 'money', 'youtube'],
#  ['find', 'love', 'life'],
#  ['option', 'better', 'reduce', 'weight', 'swimming', 'gym'],
#  ['way', 'get', 'rid', 'gynecomastia'],
#  ['payment',
#   'gateway',
#   'saudi',
#   'using',
#   'collect',
#   'pay',
#   'money',
#   'fromto',
#   'multiple'],
#  ['scientific', 'reasons', 'behind', 'hindu', 'temples'],
#  ['male', 'circumcision', 'required', 'islam'],
#  ['get',
#   'super',
#   'high',
#   'quality',
#   'photos',
#   'photo',
#   'booth',
#   'services',
#   'sydney'],
#  ['find', 'sent', 'friend', 'request', 'instagram'],
#  ['control', 'anger'],
#  ['genders'],
#  ['get', 'quora'],
#  ['long', 'raw', 'cooked', 'sausage', 'last', 'refrigerated'],
#  ['best', 'available', 'smartphones', 'gadgets'],
#  ['feel', 'closeted', 'gay', 'india'],
#  ['switch', 'roles', 'amazon'],
#  ['happens', 'dictatorship', 'continuing', 'present', 'days'],
#  ['makes', 'great', 'cup', 'coffee', 'great'],
#  ['us', 'election', 'rigged'],
#  ['gayle',
#   'laakmann',
#   'mcdowellcareercup',
#   'created',
#   'mooc',
#   'coding',
#   'bootcamp'],
#  ['fermentation', 'products', 'fermentation'],
#  ['think', 'short', 'film', 'colorshift'],
#  ['war', 'india', 'pakistan', 'kashmir'],
#  ['best', 'way', 'get', 'food', 'stamp', 'card'],
#  ['real',
#   'world',
#   'example',
#   'encapsulation',
#   'abstraction',
#   'different',
#   'yet',
#   'related'],
#  ['ways',
#   'deal',
#   'fabricate',
#   'security',
#   'insurance',
#   'android',
#   'application'],
#  ['best', 'accordion', 'beginners', 'learn'],
#  ['role', 'junior', 'leaders', 'indian', 'army'],
#  ['opinion',
#   'decision',
#   'removal',
#   'five hundred',
#   'one thousand',
#   'rupees',
#   'currency',
#   'notes'],
#  ['mindblowing', 'facts', 'bengaluru'],
#  ['parents', 'blood', 'group', 'b', 'child'],
#  ['book', 'best', 'neet', 'chemistry'],
#  ['essence', 'enlightenment'],
#  ['many',
#   'questions',
#   'posted',
#   'quora',
#   'easily',
#   'answered',
#   'using',
#   'google'],
#  ['answer',
#   'interviewer',
#   'asks',
#   'sell',
#   'pen',
#   'product',
#   'pursuing',
#   'mba'],
#  ['great', 'side', 'dishes', 'minestrone', 'soup'],
#  ['much', 'maximum', 'gold', 'take', 'flying', 'india', 'usa'],
#  ['reservation', 'status', 'rac', 'mean', 'seat', 'confirmed'],
#  ['new', 'website', 'protect', 'design', 'user', 'interface', 'copycats'],
#  ['improve', 'skills'],
#  ['possible', 'use', 'spi', 'avr', 'raspberry', 'pi'],
#  ['best', 'movies', 'two thousand and sixteen'],
#  ['would', 'effect', 'five hundred', 'one thousand', 'rs', 'notes', 'ban'],
#  ['best', 'photos'],
#  ['students', 'run', 'away', 'home'],
#  ['c', 'access', 'modifiers'],
#  ['analyze', 'history', 'unscientific'],
#  ['interesting', 'theories', 'life', 'death'],
#  ['need', 'get', 'tetanus', 'shot'],
#  ['light', 'bend', 'gravity'],
#  ['mean', 'hike', 'skirt'],
#  ['many', 'new', 'cars', 'sold', 'maserati', 'us', 'year'],
#  ['send', 'private', 'message', 'someone', 'following', 'quora'],
#  ['train', 'white', 'pitbull', 'brown', 'spots'],
#  ['difference', 'turkey', 'chicken'],
#  ['surreal', 'questions', 'asked', 'quora'],
#  ['difference', 'computer', 'science', 'engineering'],
#  ['best', 'time', 'sex'],
#  ['consult', 'good', 'free', 'online', 'astrologer'],
#  ['feel', 'sympathy', 'towards', 'everyone'],
#  ['brothers', 'hate', 'sisters'],
#  ['best', 'site', 'downloading', 'kannada', 'films', 'torrent', 'form'],
#  ['gruesome', 'causes', 'death'],
#  ['latency', 'telecom'],
#  ['senior', 'residency', 'hindu', 'rao', 'hospital', 'teaching', 'experience'],
#  ['behavioral', 'adaptations', 'pandas'],
#  ['textile', 'engineering', 'good'],
#  ['fastest', 'production', 'car'],
#  ['magnets', 'made'],
#  ['street', 'value', 'a332'],
#  ['qualifications', 'fbi', 'cia', 'agent'],
#  ['best', 'operating', 'system', 'pc', 'two thousand and fourteen'],
#  ['major', 'indian', 'tv', 'channels', 'absent', 'northeast'],
#  ['hypothetical',
#   'scenario',
#   'actual',
#   'credit',
#   'card',
#   'system',
#   'banking',
#   'never',
#   'existed',
#   'would',
#   'implement',
#   'digital',
#   'currency',
#   'internet',
#   'today'],
#  ['quora', 'quickly', 'mark', 'questions', 'needing', 'improvement'],
#  ['contact', 'good', 'hacker'],
#  ['best', 'horror', 'novel', 'two thousand and sixteen'],
#  ['beautiful', 'thing', 'ever', 'seen'],
#  ['important', 'things', 'living', 'good', 'life'],
#  ['meaning', 'purpose', 'life'],
#  ['friends', 'betray'],
#  ['fifteen',
#   'year',
#   'old',
#   'height',
#   'five',
#   'feet',
#   'seven',
#   'inches',
#   'weight',
#   'fifty',
#   'kg',
#   'gain',
#   'weight'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'china'],
#  ['different',
#   'price',
#   'internet',
#   'person',
#   'trying',
#   'book',
#   'room',
#   'mexico',
#   'city',
#   'us'],
#  ['venuetastic', 'fail'],
#  ['amazing', 'responses', 'got', 'cortana', 'siri', 'amazon', 'echo'],
#  ['important', 'life', 'money', 'values'],
#  ['best', 'hackers', 'india'],
#  ['indian', 'education', 'system', 'changed'],
#  ['multiple', 'uses', 'hollow', 'columns'],
#  ['commonly', 'mispronounced', 'words'],
#  ['every',
#   'teen',
#   'girl',
#   'crush',
#   'mathematics',
#   'teacher',
#   'intelligence',
#   'behavior'],
#  ['late', 'go', 'medical', 'school', 'become', 'doctor'],
#  ['buy',
#   'best',
#   'quality',
#   'commercial',
#   'innerspring',
#   'sofa',
#   'bed',
#   'chatswood',
#   'west'],
#  ['screenshot',
#   'someone',
#   'instagram',
#   'video',
#   'get',
#   'notified',
#   'screenshotted'],
#  ['government',
#   'exams',
#   'gate',
#   'final',
#   'year',
#   'computer',
#   'science',
#   'students',
#   'give'],
#  ['sentences', 'use', 'twentysix', 'letters', 'without', 'repeats'],
#  ['effect', 'hypodensity', 'white', 'matter', 'parietal', 'lobe', 'brain'],
#  ['job', 'salary', 'satisfied', 'current', 'job'],
#  ['psychopaths', 'find', 'babies', 'cute'],
#  ['opera', 'song', 'choir', 'used', 'horror', 'movies'],
#  ['would',
#   'woman',
#   'catholic',
#   'church',
#   'shunned',
#   'ostracized',
#   'sexual',
#   'relationship',
#   'priest'],
#  ['canadian',
#   'gets',
#   'tattoo',
#   'america',
#   'declare',
#   'cost',
#   'returning',
#   'canada'],
#  ['see', 'blocked', 'facebook'],
#  ['scarcity', 'high', 'quality', 'fantasy', 'films'],
#  ['great', 'coders', 'tamil', 'nadu'],
#  ['think', 'hear', 'word', 'elect'],
#  ['best', 'programming', 'language', 'learn', 'two thousand and seventeen'],
#  ['ultimate', 'way', 'serve', 'humanity'],
#  ['calculate', 'seventytwo', 'hours'],
#  ['hard', 'jimmy', 'wales', 'immigrate', 'uk'],
#  ['cochin',
#   'london',
#   'etihad',
#   'change',
#   'time',
#   '1hr',
#   'sufficient',
#   'dubai'],
#  ['quora', 'algorithm', 'sorting', 'answers', 'single', 'question'],
#  ['resolution', 'one', 'year', 'two thousand and sixteen'],
#  ['balaji', 'viswanathan', 'views', 'caste', 'based', 'reservations', 'india'],
#  ['jawed', 'habib', 'haircut', 'prices'],
#  ['one', 'ebook', 'answers', 'wren', 'martin', 'grammer', 'composition'],
#  ['math',
#   'x',
#   'math',
#   'math',
#   'xleft',
#   'dfrac',
#   'one',
#   'x',
#   'right',
#   'zero',
#   'math'],
#  ['whenever',
#   'special',
#   'feeling',
#   'tried',
#   'hard',
#   'forget',
#   'alwys',
#   'spcl',
#   'stop',
#   'talking',
#   'even',
#   'friend'],
#  ['mutual', 'funds', 'work'],
#  ['vertebral', 'column', 'anatomy', 'changed', 'time'],
#  ['acoustic', 'bass', 'guitar', 'best'],
#  ['universities',
#   'us',
#   'offer',
#   'management',
#   'content',
#   'management',
#   'information',
#   'systems',
#   'curriculum'],
#  ['maths',
#   'become',
#   'extremely',
#   'weak',
#   'class',
#   '12th',
#   'improve',
#   'maths',
#   'clear',
#   'jee',
#   'exams',
#   'next',
#   'year'],
#  ['function', 'context', 'functional', 'programming'],
#  ['main', 'difference', 'socialism', 'communism'],
#  ['change', 'facebook', 'password'],
#  ['word', 'valiant', 'used', 'sentence'],
#  ['feel',
#   'dizzy',
#   'playing',
#   '3d',
#   'games',
#   'others',
#   'make',
#   'feel',
#   'like',
#   'tricks',
#   'developing',
#   '3d',
#   'games',
#   'avoid'],
#  ['payroll', 'companies', 'make', 'money'],
#  ['underrated', 'overrated', 'movies', 'seen'],
#  ['use',
#   'cases',
#   'think',
#   'deep',
#   'learning',
#   'neural',
#   'networks',
#   'overkill',
#   'simpler',
#   'models',
#   'work',
#   'better',
#   'practice'],
#  ['one', 'learn', 'c', 'c'],
#  ['fitbit', 'accurately', 'track', 'activity', 'riding', 'bike'],
#  ['best', 'evidence', 'historical', 'jesus'],
#  ['free',
#   'online',
#   'language',
#   'classes',
#   'would',
#   'allow',
#   'go',
#   'zero',
#   'fluent',
#   'portuguese',
#   'given',
#   'provided',
#   'courses',
#   'study'],
#  ['pm', 'prez', 'get', 'women'],
#  ['best', 'parttime', 'jobs', 'work', 'home', 'make', 'good', 'cash'],
#  ['trump', 'chance', 'winning', 'presidency'],
#  ['shift', 'job', 'ecommerce', 'cloud', 'computing'],
#  ['meet', 'suresh', 'raina'],
#  ['name',
#   'song',
#   'picturized',
#   'madhuri',
#   'dixit',
#   'ranbir',
#   'kapoor',
#   'movie'],
#  ['function', 'nucleoplasm', 'plant', 'cell'],
#  ['fossil', 'records', 'used', 'evidence', 'evolution'],
#  ['hizmet', 'movement'],
#  ['could',
#   'cat',
#   'exam',
#   'mat',
#   'exam',
#   'take',
#   'place',
#   'day',
#   '4th',
#   'december',
#   'two thousand and sixteen'],
#  ['mythical', 'creatures', 'bible'],
#  ['one', 'good', 'oral', 'anal', 'vaginal', 'sex'],
#  ['winter', 'weather', 'conditions', 'like', 'cincinnati', 'oh'],
#  ['stocks', 'best', 'invest', 'right'],
#  ['improve', 'reading', 'skills', 'children'],
#  ['someone', 'posted', 'porn', 'video', 'name'],
#  ['lose', 'nutrients', 'calories', 'diarrhea'],
#  ['safety',
#   'precautions',
#   'handling',
#   'shotguns',
#   'proposed',
#   'nra',
#   'alaska'],
#  ['benefit', 'going', 'walking', 'every', 'morning'],
#  ['martial',
#   'artists',
#   'started',
#   'later',
#   'life',
#   'went',
#   'become',
#   'champions'],
#  ['get', 'ex', 'back'],
#  ['framework', 'choose', 'crossplatform', 'mobile', 'development'],
#  ['best', 'way', 'prepare', 'ielts'],
#  ['know', 'girl', 'dating', 'online', 'truly', 'live', 'real'],
#  ['area',
#   'games',
#   'programming',
#   'mathematically',
#   'involved',
#   'suited',
#   'math',
#   'major'],
#  ['differences', 'larceny', 'robbery'],
#  ['graph', 'theory', 'counted', 'prerequisite', 'machine', 'learning'],
#  ['best', 'schools', 'study', 'natural', 'language', 'processing', 'india'],
#  ['ted', 'cruz', 'supporters', 'vote', 'donald', 'trump'],
#  ['gdp'],
#  ['blind', 'trust', 'provision', 'american', 'presidents', 'enforced'],
#  ['make', 'girl', 'newly', 'joined', 'junior', 'college', 'fall', 'love'],
#  ['home', 'remedies', 'piles', 'anal', 'fissure'],
#  ['many',
#   'words',
#   'actually',
#   'needed',
#   'learn',
#   'gre',
#   'correct',
#   'method',
#   'prepare',
#   'gre',
#   'verbal'],
#  ['soul', 'immortal'],
#  ['personal', 'moon', '3rd', 'house', 'stories', 'experiences'],
#  ['done', 'reduce', 'pollution', 'india'],
#  ['government', 'liasioning', 'legal', 'india'],
#  ['meaning', 'got', 'take', 'shit'],
#  ['best',
#   'place',
#   'celebrate',
#   'new',
#   'year',
#   'two thousand and seventeen',
#   'hyderabad'],
#  ['working', 'hard', 'terms', 'studying'],
#  ['upgrade',
#   'windows',
#   'thirtytwo',
#   'bit',
#   'sixtyfour',
#   'bit',
#   'windows',
#   'eightyone'],
#  ['bad', 'experiences', 'life'],
#  ['timbaland', 'famous'],
#  ['get', 'list', 'individual', 'telephone', 'numbers'],
#  ['wake', 'rem', 'sleep', 'remember', 'dreams'],
#  ['common', 'required', 'elective', 'courses', 'agriculture'],
#  ['learn', 'sing'],
#  ['capable', 'ending', 'google', 'monopoly', 'search'],
#  ['auto', 'immune', 'disease', 'insomnia'],
#  ['gta', 'iv', 'work', 'windows', 'seven'],
#  ['best', 'ssc', 'banking', 'training', 'insititute', 'chandigarh'],
#  ['best', 'pmp', 'certification', 'course', 'provider', 'bangalore'],
#  ['difference', 'net', 'gross', 'income'],
#  ['wake', 'early', 'morning'],
#  ['love'],
#  ['missed', 'iit'],
#  ['difference', 'iphone', '6s', 'iphone', '6s', 'plus'],
#  ['one', 'improve', 'credit', 'score', 'one hundred', 'points'],
#  ['crush', 'likes', 'back'],
#  ['powerful', 'character', 'skyrim', 'apart', 'alduin'],
#  ['muslim',
#   'guy',
#   'date',
#   'non',
#   'muslim',
#   'girl',
#   'based',
#   'religious',
#   'individual',
#   'factors'],
#  ['comments', 'picture'],
#  ['roads', 'slippery', 'rain'],
#  ['prove', 'heisenberg', 'uncertainty', 'principle', 'experimentally'],
#  ['ielts'],
#  ['lose', 'weight', 'without', 'sport'],
#  ['digital', 'cameras', 'shutter', 'sound'],
#  ['like', 'dating', 'gangster'],
#  ['main', 'important', 'political', 'causes', 'world', 'war', 'one'],
#  ['get', 'fear', 'everything'],
#  ['city', 'india', 'best', 'weather'],
#  ['difference', 'hdd', 'ssd', 'layman', 'terms'],
#  ['mean', 'dog', 'vomits', 'white', 'foam'],
#  ['life', 'hold', 'significance', 'worlduniverse'],
#  ['job', 'situation', 'new', 'zealand', 'computer', 'science', 'graduates'],
#  ['would', 'develop', 'ecommerce', 'website'],
#  ['get', 'micro', 'sim', 'card', 'iphone', 'four'],
#  ['improve', 'question', 'quora'],
#  ['one',
#   'people',
#   'catches',
#   'feelings',
#   'established',
#   'friends',
#   'benefits',
#   'arrangement',
#   'drop',
#   'feelings',
#   'going',
#   'forward'],
#  ['tips', 'someone', 'trying', 'teach', 'sing'],
#  ['climate',
#   'change',
#   'scientists',
#   'right',
#   'worry',
#   'much',
#   'public',
#   'relations',
#   'packaging'],
#  ['main', 'reason', 'problems', 'india'],
#  ['good', 'substitute', 'milk', 'macaroni', 'cheese'],
#  ['constipation', 'dizziness'],
#  ['possible',
#   'make',
#   'doctor',
#   'review',
#   'app',
#   'using',
#   'patients',
#   'share',
#   'anonymously',
#   'treatment',
#   'given',
#   'doctor',
#   'suggested',
#   'medicines'],
#  ['pros', 'cons', 'hillary', 'clinton', 'presidency'],
#  ['best', 'films', 'take', 'place', 'one', 'room'],
#  ['normal', 'sperm', 'shoot', 'ejaculation'],
#  ['best', 'coaching', 'center', 'ssc', 'banking', 'chandigarh'],
#  ['next',
#   'number',
#   'series',
#   'one hundred and eleven million two hundred and twentytwo thousand six hundred and sixtysix'],
#  ['best', 'things', 'halloween'],
#  ['wish',
#   'start',
#   'investing',
#   'equity',
#   'mutual',
#   'funds',
#   'open',
#   'demat',
#   'account',
#   'best',
#   'rates',
#   'transaction',
#   'charges',
#   'nri'],
#  ['companies', 'issue', 'bonus', 'shares'],
#  ['changing',
#   'five hundred',
#   'one thousand',
#   'rupee',
#   'notes',
#   'end',
#   'black',
#   'money',
#   'india'],
#  ['major', 'college', 'leave', 'unemployed', 'engineering', 'law', 'medicine'],
#  ['best', 'custom', 'kiosk', 'manufacturers', 'india'],
#  ['telescopes',
#   'powerful',
#   'enough',
#   'view',
#   'evidence',
#   'left',
#   'behind',
#   'nasa',
#   'moon',
#   'landings'],
#  ['architectural',
#   'complexcenterforumhub',
#   'anywhere',
#   'world',
#   'third',
#   'space'],
#  ['many',
#   'keywords',
#   'autohotkey',
#   'scripting',
#   'programming',
#   'language',
#   'latest',
#   'version'],
#  ['hardest', 'thing', 'raising', 'children', 'ukraine'],
#  ['best', 'source', 'learn', 'stock', 'market', 'online'],
#  ['india',
#   'sabotage',
#   'badmouth',
#   'economic',
#   'projects',
#   'neighbouring',
#   'counries',
#   'world'],
#  ['wet', 'vagina', 'feel', 'like', 'man'],
#  ['thursday',
#   'night',
#   'football',
#   'increase',
#   'ratings',
#   'cbs',
#   'thursday',
#   'nights',
#   'rather',
#   'big',
#   'bang',
#   'theory'],
#  ['grow', 'taller', 'seventeen'],
#  ['ever', 'fired'],
#  ['earth',
#   'would',
#   'dress',
#   'like',
#   'workout',
#   'guy',
#   'year',
#   'one thousand nine hundred and ninety',
#   'summer'],
#  ['girlfriend', 'stopped', 'talking'],
#  ['real',
#   'estate',
#   'look',
#   'like',
#   'five hundred',
#   'one thousand',
#   'scraping'],
#  ['best', 'interview', 'questions', 'ever', 'asked'],
#  ['trust',
#   'people',
#   'quickly',
#   'result',
#   'always',
#   'betrayed',
#   'trust',
#   'people',
#   'still',
#   'hold',
#   'relation',
#   'simple'],
#  ['best', 'headhunters', 'mumbai'],
#  ['dhp', 'vaccine', 'dogs', 'necessary'],
#  ['differences', 'asia', 'africa', 'similarities'],
#  ['wizard', 'magic', 'scientifically', 'tested'],
#  ['contract', 'law', 'important'],
#  ['moto',
#   'g3',
#   'moto',
#   'g',
#   '3rd',
#   'gen',
#   'two thousand and fifteen',
#   'get',
#   'android',
#   'seventy',
#   'nougat',
#   'update'],
#  ['prove', 'snr', 'power', 'snr', 'voltage', 'sequare'],
#  ['best', 'riddles', 'riddler', 'batman'],
#  ['much', 'nudity', 'content', 'game', 'thrones'],
#  ['get', 'followers', 'comments', 'blog'],
#  ['two', 'months', 'ca', 'cpt', 'exams', 'prepare'],
#  ['programming', 'language', 'learn', 'want', '2d', 'mmorpg', 'game'],
#  ['view', 'recent', 'demonetization', 'india'],
#  ['cyrus', 'mistry', 'removed'],
#  ['cancel', 'usaa', 'auto', 'insurance'],
#  ['angry', 'lately'],
#  ['form', 'hypothesis', 'since', 'done', 'testing', 'test', 'results', 'yet'],
#  ['consequences', 'trolling'],
#  ['frightened', 'arvind', 'kejriwal', 'may', 'kill', 'shall'],
#  ['disadvantages', 'apple', 'computerslaptops', 'brands'],
#  ['first', 'moment', 'remember', 'life'],
#  ['completing', 'bds'],
#  ['muslims', 'hate', 'narendra', 'modi'],
#  ['eighteen'],
#  ['really', 'good', 'famous', 'romantic', 'comedy', 'movies'],
#  ['realistic',
#   'get',
#   'second',
#   'bachelors',
#   'degree',
#   'math',
#   'international',
#   'student',
#   'holding',
#   'first',
#   'bachelors',
#   'degree',
#   'accounnting'],
#  ['possible',
#   'believe',
#   'old',
#   'testament',
#   'one',
#   'god',
#   'time',
#   'believe',
#   'trinity'],
#  ['start', 'meditating'],
#  ['infinite',
#   'amount',
#   'dark',
#   'vacuum',
#   'gravitational',
#   'energy',
#   'created',
#   'expansion'],
#  ['bihar', 'really', 'developing', 'mahagathbandhan', 'sarkar'],
#  ['homeopathic', 'medicine', 'sideeffects'],
#  ['determine', 'good', 'investment', 'brokerage'],
#  ['scope', 'supply', 'chain', 'management', 'india'],
#  ['number', 'pistons', 'equal', 'number', 'number', 'cylinders'],
#  ['post', 'picture', 'social', 'media'],
#  ['control', 'actions', 'dream'],
#  ['managed', 'long', 'distance', 'relationship'],
#  ['chances',
#   'could',
#   'ask',
#   'rich',
#   'person',
#   'million',
#   'dollars',
#   'actually',
#   'give'],
#  ['happened', 'hong', 'kong', 'movies', 'tv', 'drama', 'decline', 'much'],
#  ['trump', 'win', 'election'],
#  ['best', 'wallpaper', 'apps', 'iphones'],
#  ['deactivate', 'app', 'app', 'lock'],
#  ['format', 'send', 'book', 'printing'],
#  ['caste', 'system', 'still', 'exist', 'india'],
#  ['get', 'boyfriend', 'age', 'thirteen'],
#  ['rank',
#   'five hundred and fifty',
#   'marks',
#   'neet',
#   'two thousand and sixteen'],
#  ['dynamicflexipricing', 'harsh', 'middle', 'class', 'people'],
#  ['overdraft', 'wells', 'fargo', 'account'],
#  ['new', 'marketing', 'techniques', 'language', 'schools'],
#  ['much', 'olympic', 'gold', 'medalists', 'earn'],
#  ['easy', 'ways', 'earn', 'money', 'online'],
#  ['reactance', 'capacitor'],
#  ['true',
#   'cost',
#   'living',
#   'sv',
#   'bay',
#   'area',
#   'high',
#   'new',
#   'grads',
#   'making',
#   '150k',
#   'hard',
#   'time',
#   'finding',
#   'affordable',
#   'housing'],
#  ['best', 'school', 'world'],
#  ['saltwater', 'taffy', 'candy', 'imported', 'australia'],
#  ['value', 'zero'],
#  ['best', 'parttime', 'jobs', 'bangalore'],
#  ['become', 'attractive', 'girl'],
#  ['best', 'music', 'albums', 'ever'],
#  ['realistically',
#   'speaking',
#   'would',
#   'happen',
#   'usa',
#   'donald',
#   'trump',
#   'wins',
#   'presidency',
#   'two thousand and sixteen',
#   'elections'],
#  ['symptoms', 'autism', 'kids'],
#  ['like', 'nonsmoking', 'mother', 'smoking', 'children'],
#  ['life', 'without', 'dreams'],
#  ['comfortably', 'live', 'washington', 'dc', 'eighty thousand', 'salary'],
#  ['find', 'girl', 'boyfriend'],
#  ['health', 'benefits', 'red', 'lentils'],
#  ['math', 'related', 'working', 'models', 'class', '10th'],
#  ['could', 'gain', 'weight', 'healthy', 'way'],
#  ['kind', 'animal'],
#  ['anil', 'ambani', 'benefit', 'rafel', 'fighter', 'jet', 'deal'],
#  ['youtube', 'red', 'offline', 'feature', 'good', 'downloading', 'video'],
#  ['know', 'spouse', 'soulmate'],
#  ['get', 'people', 'person'],
#  ['long', 'distance', 'relationship', 'work'],
#  ['speak', 'fluent', 'english'],
#  ['considering',
#   'position',
#   'secretary',
#   'state',
#   'gave',
#   'insight',
#   'us',
#   'drone',
#   'program',
#   'reform',
#   'targeting',
#   'process'],
#  ['exactly', 'mike20', 'layman', 'terms'],
#  ['buffalo',
#   'like',
#   'evolve',
#   'band',
#   'together',
#   'lions',
#   'cheetahs',
#   'instead',
#   'run',
#   'away'],
#  ['find', 'hacker', 'good'],
#  ['change', 'snapdeal', 'account', 'mobile', 'number'],
#  ['tips', 'making', 'job', 'interview', 'process', 'bank'],
#  ['main',
#   'imports',
#   'exports',
#   'venezuela',
#   'venezuela',
#   'industry',
#   'compare',
#   'cuba'],
#  ['lucifer', 'gabrielle', 'relate'],
#  ['good', 'movies', 'watch'],
#  ['install',
#   'cydia',
#   'without',
#   'jailbreak',
#   'ios',
#   'nine hundred and thirtyfive'],
#  ['get', 'job', 'microsoft'],
#  ['fahrenheit', 'four hundred and fiftyone', 'perceived', 'dystopia'],
#  ['review', 'love', 'thoughts', 'two thousand and four', 'movie'],
#  ['physically', 'possible', 'travel', 'back', 'time'],
#  ['awkward', 'people', 'others'],
#  ['recover', 'deleted', 'messages', 'facebook'],
#  ['compensation', 'system', 'uber'],
#  ['feasible',
#   'flipkart',
#   'offer',
#   'emi',
#   'debit',
#   'cards',
#   'different',
#   'factors',
#   'involved'],
#  ['define',
#   'tasks',
#   'vs',
#   'milestones',
#   'vs',
#   'deliverables',
#   'agile',
#   'scrum',
#   'methodology'],
#  ['life', 'boring'],
#  ['buy', 'meldonium', 'canada'],
#  ['would', 'cool', 'way', 'commit', 'suicide'],
#  ['accidentally', 'took', 'blood', 'pressure', 'medicine', 'twice', 'ok'],
#  ['paranormal', 'experience'],
#  ['2g', 'band', '9001800mhz', 'sold', '2g', 'spectrum', 'scam'],
#  ['straight',
#   'student',
#   'motivation',
#   'whatsoever',
#   'go',
#   'school',
#   'someone',
#   'help',
#   'fight'],
#  ['best', 'shares', 'purchase', 'sale', 'daily', 'trading'],
#  ['girlfriends', 'private', 'partstouched', 'othercan', 'become', 'pregenant'],
#  ['could',
#   'use',
#   'cherenkov',
#   'atmosphere',
#   'radiation',
#   'gamma',
#   'rays',
#   'similar',
#   'image',
#   'surface',
#   'planet',
#   'ground',
#   'based',
#   'telescopes'],
#  ['good', 'song', 'lyric', 'prank'],
#  ...]

# %% [markdown]
# **TERM FREQUENCY - INVERSE DOCUMENT FREQUENCY (TF-IDF) FEATURE EXTRACTION**

# %%
def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None)

tfidfv = tfidf.fit(docs)

# %%
tfidfv.vocabulary_
# Out:
# {'step': 87337,
#  'guide': 39991,
#  'invest': 47008,
#  'share': 82813,
#  'market': 55678,
#  'india': 45409,
#  'story': 87653,
#  'kohinoor': 50705,
#  'diamond': 26357,
#  'increase': 45298,
#  'speed': 86244,
#  'internet': 46681,
#  'connection': 21249,
#  'using': 97223,
#  'vpn': 99055,
#  'mentally': 57046,
#  'lonely': 53639,
#  'solve': 85622,
#  'one': 65053,
#  'dissolve': 27321,
#  'water': 99631,
#  'quikly': 74643,
#  'sugar': 88540,
#  'salt': 79865,
#  'methane': 57337,
#  'carbon': 16498,
#  'di': 26291,
#  'oxide': 67131,
#  'astrology': 9262,
#  'capricorn': 16424,
#  'sun': 88706,
#  'cap': 16344,
#  'moon': 59206,
#  'rising': 78304,
#  'say': 80449,
#  'buy': 15582,
#  'tiago': 92289,
#  'good': 38951,
#  'geologist': 38009,
#  'use': 97149,
#  'instead': 46328,
#  'motorola': 59497,
#  'company': 20617,
#  'hack': 40381,
#  'charter': 18001,
#  'motorolla': 59498,
#  'dcx3400': 24537,
#  'method': 57346,
#  'find': 34471,
#  'separation': 82025,
#  'slits': 84850,
#  'fresnel': 36542,
#  'biprism': 13000,
#  'read': 75672,
#  'youtube': 102972,
#  'comments': 20456,
#  'make': 54992,
#  'physics': 69933,
#  'easy': 29269,
#  'learn': 52076,
#  'first': 34633,
#  'sexual': 82574,
#  'experience': 32733,
#  'like': 52902,
#  'laws': 51898,
#  'change': 17835,
#  'status': 87226,
#  'student': 87994,
#  'visa': 98623,
#  'green': 39526,
#  'card': 16531,
#  'us': 97086,
#  'compare': 20651,
#  'immigration': 44844,
#  'canada': 16190,
#  'would': 101429,
#  'trump': 94223,
#  'presidency': 72385,
#  'mean': 56541,
#  'current': 23578,
#  'international': 46672,
#  'master': 55967,
#  'students': 88007,
#  'f1': 33069,
#  'manipulation': 55371,
#  'girls': 38430,
#  'want': 99425,
#  'friends': 36600,
#  'guy': 40197,
#  'reject': 76720,
#  'many': 55501,
#  'quora': 74708,
#  'users': 97194,
#  'posting': 71559,
#  'questions': 74576,
#  'readily': 75691,
#  'answered': 7364,
#  'google': 39006,
#  'best': 12195,
#  'digital': 26614,
#  'marketing': 55691,
#  'institution': 46353,
#  'banglore': 10980,
#  'rockets': 78532,
#  'look': 53702,
#  'white': 100482,
#  'causing': 17098,
#  'someone': 85662,
#  'jealous': 48311,
#  'ask': 8985,
#  'much': 59891,
#  'thirty': 91770,
#  'kv': 51143,
#  'hp': 43163,
#  'every': 32232,
#  'time': 92444,
#  'clock': 19501,
#  'numbers': 64034,
#  'tips': 92579,
#  'making': 55023,
#  'job': 48662,
#  'interview': 46790,
#  'process': 72792,
#  'medicines': 56700,
#  'web': 99863,
#  'application': 8022,
#  'society': 85397,
#  'place': 70388,
#  'importance': 44986,
#  'sports': 86526,
#  'way': 99734,
#  'money': 58971,
#  'online': 65852,
#  'prepare': 72271,
#  'ca': 15788,
#  'final': 34434,
#  'law': 51874,
#  'thing': 91696,
#  'better': 12294,
#  'special': 86141,
#  'cares': 16609,
#  'nose': 63577,
#  'gets': 38142,
#  'stuffy': 88060,
#  'night': 62124,
#  'game': 37346,
#  'thrones': 92187,
#  'villain': 98481,
#  'likely': 52923,
#  'give': 38466,
#  'mercy': 57111,
#  'united': 96374,
#  'states': 87178,
#  'government': 39150,
#  'still': 87456,
#  'blacklist': 13218,
#  'employment': 30755,
#  'etc': 31929,
#  'citizens': 19065,
#  'political': 71039,
#  'views': 98419,
#  'travel': 93753,
#  'website': 99952,
#  'spain': 86025,
#  'people': 68948,
#  'think': 91712,
#  'obama': 64243,
#  'try': 94288,
#  'take': 89972,
#  'guns': 40113,
#  'away': 10135,
#  '19yearold': 934,
#  'improve': 45050,
#  'skills': 84550,
#  'become': 11693,
#  'entrepreneur': 31317,
#  'next': 61950,
#  'years': 102669,
#  'girlfriend': 38415,
#  'asks': 9005,
#  'boyfriend': 14291,
#  'choose': 18629,
#  'makes': 55009,
#  'reply': 77198,
#  'upsc': 96932,
#  'stall': 86973,
#  'aoa': 7768,
#  'f14': 33073,
#  'wings': 100861,
#  'fully': 36899,
#  'swept': 89400,
#  'back': 10449,
#  'slavs': 84748,
#  'squat': 86697,
#  'expect': 32693,
#  'cognizant': 19980,
#  'confirmation': 21131,
#  'mail': 54875,
#  'fifty thousand': 34264,
#  'month': 59148,
#  'day': 24433,
#  'trading': 93424,
#  'kid': 50207,
#  'rebel': 75866,
#  'worth': 101413,
#  'long': 53644,
#  'run': 79229,
#  'universities': 96408,
#  'rexnord': 77946,
#  'recruit': 76131,
#  'new': 61860,
#  'grads': 39269,
#  'majors': 54978,
#  'looking': 53717,
#  'quickest': 74611,
#  'instagram': 46273,
#  'followers': 35467,
#  'darth': 24253,
#  'vader': 97505,
#  'fought': 35898,
#  'maul': 56190,
#  'star': 87050,
#  'wars': 99539,
#  'legends': 52265,
#  'stages': 86922,
#  'breaking': 14558,
#  'couple': 22391,
#  'happens': 40840,
#  'emotionally': 30697,
#  'whether': 100425,
#  'male': 55085,
#  'female': 33962,
#  'examples': 32356,
#  'products': 72879,
#  'crude': 23151,
#  'oil': 64779,
#  'career': 16578,
#  'launcher': 51832,
#  'rbi': 75580,
#  'grade': 39244,
#  'b': 10305,
#  'preparation': 72268,
#  'blu': 13526,
#  'ray': 75540,
#  'play': 70589,
#  'regular': 76607,
#  'dvd': 28949,
#  'player': 70598,
#  'nd': 61339,
#  'always': 6447,
#  'sad': 79577,
#  'bestmost': 12227,
#  'memorable': 56952,
#  'ever': 32214,
#  'eaten': 29287,
#  'gst': 39854,
#  'affects': 5178,
#  'cas': 16797,
#  'tax': 90441,
#  'officers': 64673,
#  'difficult': 26563,
#  'get': 38114,
#  'rsi': 79064,
#  'israil': 47586,
#  'friend': 36576,
#  'rap': 75344,
#  'songs': 85729,
#  'dance': 24114,
#  'suddenly': 88494,
#  'logged': 53536,
#  'gmail': 38681,
#  'remember': 76937,
#  'password': 68241,
#  'realized': 75766,
#  'recovery': 76119,
#  'email': 30500,
#  'longer': 53654,
#  'alive': 6098,
#  'ways': 99758,
#  'french': 36482,
#  'download': 28147,
#  'content': 21540,
#  'kickass': 50192,
#  'torrent': 93152,
#  'without': 101027,
#  'registration': 76577,
#  'normal': 63513,
#  'dark': 24214,
#  'ring': 78238,
#  'around': 8630,
#  'iris': 47300,
#  'eye': 33011,
#  'harry': 41026,
#  'potter': 71682,
#  'book': 13896,
#  'cursed': 23601,
#  'child': 18369,
#  'depressed': 25659,
#  'european': 32104,
#  'family': 33417,
#  'office': 64660,
#  'database': 24298,
#  'java': 48184,
#  'programming': 72999,
#  'language': 51574,
#  'made': 54587,
#  'store': 87621,
#  'energy': 30977,
#  'produced': 72848,
#  'lightning': 52874,
#  'review': 77862,
#  'performance': 69087,
#  'testing': 91198,
#  'cost': 22200,
#  'privacy': 72665,
#  'germany': 38080,
#  'come': 20347,
#  'else': 30470,
#  'lost': 53810,
#  'gain': 37243,
#  'types': 95337,
#  'immunity': 44861,
#  'narcissistic': 60996,
#  'personality': 69283,
#  'disorder': 27172,
#  'speak': 86124,
#  'english': 31103,
#  'fluently': 35288,
#  'helpful': 41667,
#  'quickbooks': 74607,
#  'auto': 9820,
#  'data': 24293,
#  'support': 88982,
#  'phone': 69716,
#  'number': 64020,
#  'recover': 76110,
#  'corrupted': 22099,
#  'files': 34355,
#  'richest': 78083,
#  'gambler': 37338,
#  'reach': 75629,
#  'level': 52522,
#  'fire': 34568,
#  'bullet': 15267,
#  'backward': 10562,
#  'aircraft': 5651,
#  'going': 38857,
#  'faster': 33621,
#  'backwards': 10564,
#  'prevent': 72484,
#  'breast': 14572,
#  'cancer': 16226,
#  'log': 53520,
#  'account': 4222,
#  'purpose': 73990,
#  'life': 52765,
#  'bjp': 13168,
#  'strip': 87899,
#  'muslims': 60336,
#  'christians': 18717,
#  'indian': 45437,
#  'citizenship': 19067,
#  'put': 74054,
#  'boats': 13658,
#  'rohingya': 78586,
#  'burma': 15403,
#  'right': 78176,
#  'etiquette': 32010,
#  'wishing': 100975,
#  'jehovah': 48364,
#  'witness': 101038,
#  'happy': 40852,
#  'birthday': 13037,
#  'wants': 99434,
#  'open': 65975,
#  'commercial': 20464,
#  'fm': 35358,
#  'radio': 74941,
#  'station': 87194,
#  'city': 19078,
#  'procedure': 72777,
#  'swiss': 89451,
#  'despise': 25886,
#  'asians': 8969,
#  'high': 42039,
#  'salary': 79784,
#  'income': 45257,
#  'jobs': 48684,
#  'field': 34214,
#  'biotechnology': 12974,
#  'height': 41582,
#  'twentyone': 94805,
#  'also': 6368,
#  'major': 54960,
#  'effects': 29705,
#  'cambodia': 16098,
#  'earthquake': 29227,
#  'kamchatca': 49399,
#  'earthquakes': 29231,
#  'one thousand nine hundred and fiftytwo': 65516,
#  'difference': 26517,
#  'sincerity': 83960,
#  'fairness': 33322,
#  'gaming': 37396,
#  'laptop': 51643,
#  '60k': 2866,
#  'inr': 46139,
#  'warrior': 99536,
#  'proving': 73461,
#  'grounds': 39735,
#  'part': 68066,
#  'nine': 62217,
#  'reference': 76384,
#  'class': 19215,
#  '11th': 332,
#  'national': 61105,
#  'institute': 46348,
#  'technology': 90666,
#  'kurukshetra': 51113,
#  'social': 85362,
#  'nitk': 62560,
#  'surathkal': 89041,
#  'romantic': 78662,
#  'movies': 59607,
#  'causes': 17095,
#  'nightmare': 62138,
#  'abstract': 4039,
#  'expressionism': 32865,
#  'painting': 67452,
#  '3d': 2118,
#  'printing': 72616,
#  'work': 101263,
#  'attend': 9524,
#  'caltech': 16077,
#  'jeremy': 48404,
#  'ehrhardt': 29818,
#  'horcrux': 42869,
#  'associate': 9182,
#  'product': 72859,
#  'manager': 55228,
#  'apm': 7873,
#  'programs': 73012,
#  'early': 29181,
#  '20s': 1338,
#  'join': 48752,
#  'management': 55216,
#  'rewarding': 77922,
#  'skype': 84669,
#  'eighteen billion five hundred and fiftyfour million two hundred and fiftythree thousand seven hundred and sixtyeight': 29984,
#  'busy': 15533,
#  'really': 75771,
#  'war': 99444,
#  'pakistan': 67485,
#  'uri': 97044,
#  'attack': 9497,
#  'ronald': 78694,
#  'reagan': 75724,
#  'mannerism': 55407,
#  'speech': 86235,
#  'strategies': 87754,
#  'union': 96344,
#  'confederates': 21086,
#  'civil': 19100,
#  'fiction': 34193,
#  'novel': 63756,
#  'two thousand and sixteen': 95120,
#  'forgot': 35712,
#  'recent': 75944,
#  'demonetisation': 25404,
#  'results': 77637,
#  'higher': 42052,
#  'gdp': 37748,
#  'heard': 41448,
#  'hacking': 40400,
#  'love': 53859,
#  'pity': 70335,
#  'competitive': 20709,
#  'hiring': 42319,
#  'republic': 77269,
#  'bank': 10996,
#  'helps': 41678,
#  'spam': 86028,
#  'ranking': 75326,
#  'adjustment': 4810,
#  'search': 81235,
#  'watch': 99611,
#  'gonulcelen': 38945,
#  'subtitles': 88391,
#  'usa': 97087,
#  'powerful': 71748,
#  'country': 22369,
#  'world': 101353,
#  'obtain': 64393,
#  'instant': 46315,
#  'ulcer': 95642,
#  'pain': 67424,
#  'relief': 76840,
#  'china': 18431,
#  'food': 35515,
#  'taking': 89997,
#  'advantage': 4981,
#  'cry': 23213,
#  'stick': 87430,
#  'tongues': 92938,
#  'pictures': 70037,
#  'ending': 30905,
#  'one thousand nine hundred and eightyfour': 65498,
#  'depressing': 25664,
#  'mindblowing': 57991,
#  'computer': 20875,
#  'tools': 92981,
#  'exist': 32609,
#  'know': 50631,
#  'toothbrush': 92998,
#  'wet': 100286,
#  'dry': 28594,
#  'applying': 8050,
#  'toothpaste': 93003,
#  'question': 74558,
#  'marked': 55675,
#  'needing': 61443,
#  'imrovement': 45088,
#  'neutral': 61831,
#  'state': 87153,
#  'buffer': 15142,
#  'mineral': 58033,
#  'holds': 42562,
#  'highest': 42064,
#  'electrical': 30200,
#  'charge': 17951,
#  'greatest': 39496,
#  'mystery': 60586,
#  'universe': 96398,
#  'alternative': 6393,
#  'machine': 54506,
#  'learning': 52091,
#  'block': 13407,
#  'sanctions': 80000,
#  'un': 95737,
#  'jaishemohammad': 47998,
#  'jem': 48378,
#  'chief': 18347,
#  'masood': 55924,
#  'azhar': 10280,
#  'future': 37073,
#  'budget': 15123,
#  'excessive': 32427,
#  'amounts': 6745,
#  'vitamin': 98740,
#  'c': 15677,
#  'miscarriage': 58229,
#  'asahi': 8834,
#  'glass': 38529,
#  'pay': 68473,
#  'scale': 80515,
#  'two': 94911,
#  'access': 4163,
#  'torbox': 93111,
#  'yakshini': 102526,
#  'mantras': 55464,
#  'six': 84235,
#  'party': 68150,
#  'talks': 90049,
#  'successful': 88441,
#  'register': 76565,
#  'domain': 27820,
#  'site': 84166,
#  'older': 64858,
#  'men': 56985,
#  'attracted': 9568,
#  'young': 102911,
#  'women': 101149,
#  'strongest': 87924,
#  'structure': 87950,
#  'shape': 82794,
#  'compression': 20833,
#  'matter': 56159,
#  'humans': 43416,
#  'selfish': 81692,
#  'evil': 32266,
#  'exocytosis': 32647,
#  'endocytosis': 30916,
#  'active': 4501,
#  'passive': 68223,
#  'transport': 93692,
#  'hair': 40479,
#  'bald': 10786,
#  'head': 41337,
#  'ideal': 44213,
#  'retirement': 77716,
#  'stance': 86998,
#  'websites': 99964,
#  'escorts': 31783,
#  'polo': 71079,
#  'diesel': 26483,
#  'grand': 39332,
#  'i10': 43905,
#  'petrol': 69423,
#  'black': 13184,
#  'hole': 42563,
#  'mass': 55930,
#  'morgan': 59279,
#  'freeman': 36414,
#  'correct': 22049,
#  'says': 80463,
#  'stop': 87600,
#  'racism': 74878,
#  'talking': 90045,
#  'fab': 33148,
#  'currently': 23585,
#  'offer': 64643,
#  'employees': 30746,
#  'stock': 87523,
#  'options': 66214,
#  'rsus': 79080,
#  'waveclues': 99703,
#  'distribute': 27389,
#  'ten': 90906,
#  'identical': 44243,
#  'pencils': 68844,
#  'four': 35921,
#  'least': 52122,
#  'pencil': 68843,
#  'hire': 42308,
#  'jerry': 48414,
#  'seinfeld': 81545,
#  'twelve': 94671,
#  'hours': 43075,
#  'seven': 82256,
#  'days': 24466,
#  'late': 51746,
#  'rabies': 74845,
#  'vaccine': 97488,
#  'possible': 71484,
#  'nonbite': 62854,
#  'exposure': 32851,
#  'britain': 14753,
#  'ruled': 79199,
#  'afraid': 5234,
#  'working': 101297,
#  'red': 76182,
#  'keep': 49802,
#  'keys': 50004,
#  'oitnb': 64799,
#  'age': 5328,
#  'lose': 53792,
#  'virginity': 98590,
#  'forgetful': 35696,
#  'could': 22286,
#  'snoke': 85245,
#  'secretly': 81362,
#  'monetize': 58968,
#  'videos': 98362,
#  'upload': 96895,
#  'copyright': 21913,
#  'chances': 17806,
#  'may': 56261,
#  'switch': 89455,
#  'canon': 16304,
#  '6d': 2966,
#  'leica': 52324,
#  'dlux': 27571,
#  'one hundred and nine': 65145,
#  'members': 56929,
#  'moderation': 58707,
#  'nobody': 62686,
#  'answer': 7360,
#  'funniest': 36993,
#  'joke': 48777,
#  'got': 39102,
#  'chelmsfordessex': 18194,
#  'london': 53628,
#  'three thousand seven hundred and sixtyfour': 92104,
#  'pm': 70783,
#  'payafter': 68475,
#  'deduction': 24930,
#  'pls': 70709,
#  'advice': 5026,
#  'tentative': 91012,
#  'monthly': 59154,
#  'expenses': 32725,
#  'saving': 80411,
#  'stereotypes': 87378,
#  'kingdom': 50348,
#  'twitter': 94904,
#  'business': 15476,
#  'source': 85907,
#  'transfer': 93580,
#  'skrill': 84630,
#  'paypal': 68514,
#  'earphone': 29201,
#  'deep': 24948,
#  'bass': 11323,
#  'one thousand': 65341,
#  'eligible': 30380,
#  'sukanya': 88603,
#  'samrudi': 79960,
#  'yojana': 102839,
#  'forward': 35874,
#  'engineering': 31057,
#  'fields': 34222,
#  'suit': 88587,
#  'abusing': 4067,
#  'gross': 39714,
#  'ctc': 23360,
#  'prospering': 73297,
#  'towns': 93320,
#  'kerala': 49899,
#  'confidence': 21107,
#  'anyone': 7744,
#  'see': 81451,
#  'relation': 76758,
#  'greek': 39518,
#  'gods': 38819,
#  'hindu': 42246,
#  'apple': 7998,
#  'music': 60288,
#  'spotify': 86551,
#  'fixed': 34926,
#  'fund': 36936,
#  'live': 53272,
#  'cologne': 20205,
#  'robert': 78468,
#  'de': 24573,
#  'niro': 62514,
#  'al': 5836,
#  'pacino': 67283,
#  'prefer': 72132,
#  'small': 84948,
#  'families': 33415,
#  'animals': 7182,
#  'kiss': 50431,
#  'deleted': 25220,
#  'chats': 18048,
#  'addicted': 4665,
#  'hired': 42310,
#  'private': 72668,
#  'eyes': 33030,
#  'ordered': 66298,
#  'follow': 35461,
#  'startup': 87122,
#  'accelerator': 4133,
#  'check': 18121,
#  'wifi': 100665,
#  'history': 42365,
#  'android': 7044,
#  'phones': 69737,
#  'significance': 83711,
#  'battle': 11414,
#  'somme': 85691,
#  'contrast': 21635,
#  'rostov': 78798,
#  'creative': 22781,
#  'college': 20126,
#  'admissions': 4855,
#  'essay': 31849,
#  'happen': 40829,
#  'cover': 22482,
#  'patch': 68288,
#  'year': 102643,
#  'pursue': 74009,
#  'different': 26532,
#  'things': 91701,
#  'ben': 11971,
#  'affleck': 5204,
#  'shine': 83108,
#  'christian': 18705,
#  'bale': 10794,
#  'batman': 11384,
#  'start': 87098,
#  'hyderabad': 43629,
#  'possessive': 71476,
#  'wife': 100653,
#  'lord': 53764,
#  'krishna': 50934,
#  'combination': 20311,
#  'courses': 22428,
#  'along': 6309,
#  'enhance': 31138,
#  'screenshot': 81043,
#  'mac': 54453,
#  'executive': 32511,
#  'recruiter': 76133,
#  'psychological': 73641,
#  'need': 61437,
#  'collecting': 20113,
#  'fulfill': 36847,
#  'must': 60346,
#  'tv': 94620,
#  'shows': 83427,
#  'die': 26457,
#  'fluent': 35286,
#  'chinese': 18453,
#  'demonitization': 25421,
#  'five hundred': 34734,
#  'rupees': 79274,
#  'notes': 63644,
#  'real': 75729,
#  'estate': 31877,
#  'sector': 81376,
#  'easiest': 29245,
#  'billionaire': 12788,
#  'willing': 100758,
#  'free': 36355,
#  'lectures': 52168,
#  'conduct': 21059,
#  'workshop': 101334,
#  'colleges': 20140,
#  'robotics': 78492,
#  'hate': 41131,
#  'hillary': 42177,
#  'clinton': 19455,
#  'periods': 69129,
#  'regarded': 76519,
#  'unclean': 95864,
#  'prevented': 72488,
#  'actived': 4505,
#  'rituals': 78331,
#  'hinduism': 42249,
#  'atheism': 9353,
#  'lack': 51316,
#  'belief': 11891,
#  'term': 91050,
#  'god': 38785,
#  'jack': 47902,
#  'dorsey': 28016,
#  'quoteslessons': 74749,
#  'assassin': 9099,
#  'creed': 22825,
#  'series': 82107,
#  'inkjet': 46020,
#  'printers': 72613,
#  'color': 20235,
#  'ink': 46018,
#  'documents': 27685,
#  'creativity': 22790,
#  'important': 44988,
#  'continue': 21587,
#  'presidential': 72390,
#  'campaign': 16141,
#  'democratic': 25377,
#  'candidate': 16244,
#  'headphones': 41371,
#  'antenna': 7410,
#  'channels': 17875,
#  'mobile': 58606,
#  'companies': 20601,
#  'install': 46287,
#  'inbuilt': 45168,
#  'able': 3913,
#  'growth': 39784,
#  'technologies': 90661,
#  'automation': 9887,
#  'engineers': 31083,
#  'apart': 7803,
#  'disadvantages': 26887,
#  'listing': 53199,
#  'nse': 63884,
#  'derivatives': 25713,
#  'object': 64286,
#  'position': 71440,
#  'respect': 77513,
#  'continuous': 21594,
#  'neutron': 61842,
#  'thirtyeight': 91780,
#  'gpa': 39198,
#  'enough': 31191,
#  'top': 93009,
#  'harvard': 41049,
#  'profitable': 72945,
#  'trade': 93398,
#  'binary': 12819,
#  'utilize': 97323,
#  'avoid': 10075,
#  'depression': 25665,
#  'security': 81413,
#  'earn': 29185,
#  'puk': 73791,
#  'code': 19841,
#  'japan': 48116,
#  'sentences': 81983,
#  'word': 101224,
#  'hysteria': 43890,
#  'another': 7336,
#  'billion': 12787,
#  'dollar': 27797,
#  'lottery': 53828,
#  'jackpot': 47918,
#  'scary': 80612,
#  'drive': 28452,
#  'road': 78416,
#  'hana': 40674,
#  'given': 38471,
#  'turns': 94559,
#  'create': 22760,
#  'terminal': 91054,
#  'linux': 53098,
#  'cognition': 19972,
#  'affect': 5168,
#  'perception': 69034,
#  'tqwl': 93358,
#  'ckwl': 19133,
#  'tatkal': 90398,
#  'waiting': 99291,
#  'list': 53185,
#  'generations': 37889,
#  'champions': 17792,
#  'league': 52042,
#  'drinking': 28441,
#  'liters': 53226,
#  'unhealthy': 96261,
#  'great': 39492,
#  'lakes': 51419,
#  'wildlife': 100727,
#  'lake': 51413,
#  'prespa': 72401,
#  'porn': 71349,
#  'stars': 87092,
#  'supporters': 88989,
#  'feel': 33905,
#  'walking': 99341,
#  'promises': 73105,
#  'worried': 101388,
#  'others': 66618,
#  'opinions': 66097,
#  'potty': 71690,
#  'train': 93467,
#  'months': 59159,
#  'pitbull': 70302,
#  'jump': 49042,
#  'rope': 78750,
#  'five': 34730,
#  'minutes': 58155,
#  'calories': 16068,
#  'test': 91163,
#  'gate': 37584,
#  'two thousand and seventeen': 95116,
#  'cs': 23254,
#  'stream': 87792,
#  'material': 56061,
#  'understanding': 96053,
#  'algorithmic': 6026,
#  'analysis': 6885,
#  'newbie': 61864,
#  'temperament': 90867,
#  'bullmastiffhusky': 15286,
#  'mix': 58433,
#  'eight': 29844,
#  'balls': 10838,
#  'weigh': 100066,
#  'weight': 100072,
#  'heavier': 41520,
#  'lighter': 52860,
#  'odd': 64536,
#  'ball': 10811,
#  'weighs': 100071,
#  'raisin': 75093,
#  'walter': 99388,
#  'ad': 4596,
#  'beneatha': 11994,
#  'argue': 8477,
#  'signs': 83731,
#  'ultra': 95668,
#  'smart': 84972,
#  'person': 69267,
#  'playing': 70608,
#  'dumb': 28781,
#  'created': 22763,
#  'expansion': 32682,
#  'infinite': 45746,
#  'published': 73742,
#  'disrupting': 27278,
#  'bloomberg': 13487,
#  'flash': 35011,
#  'fast': 33606,
#  'legally': 52250,
#  'tangible': 90169,
#  'profits': 72957,
#  'relatively': 76781,
#  'short': 83307,
#  'period': 69120,
#  'implementation': 44957,
#  'bill': 12766,
#  'impact': 44881,
#  'lives': 53296,
#  'common': 20513,
#  'accurately': 4280,
#  'mental': 57040,
#  'illness': 44685,
#  'diagnosed': 26309,
#  'knee': 50575,
#  'twenty': 94711,
#  'old': 64853,
#  'girl': 38405,
#  'qualities': 74405,
#  'leader': 52020,
#  'bay': 11446,
#  'gulf': 40051,
#  'straits': 87716,
#  'modi': 58735,
#  ...}

# %%
vectors = tfidfv.transform(docs)

#Use Truncated SVD for dimension reduction on the TFIDF matrix
trunc = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=10, random_state=0)
trunc_vec = trunc.fit_transform(vectors)
tfidf_vec = pd.DataFrame(trunc_vec)

#Save processed tfidf vectors for later use
tfidf_vec.to_pickle('tfidf_vec.pkl')

# %%
# tfidf_vec = pd.DataFrame([vectors])
tfidf_vec
# Out:
#                   0             1             2             3             4   \
# 0       3.554628e-02  1.980797e-02  9.476206e-03 -4.349222e-02 -3.302893e-02
# 1       2.004909e-03  6.691434e-04 -8.344218e-04 -1.691031e-03 -6.183989e-04
# 2       1.567654e-02  1.875925e-02  1.806812e-03 -2.495301e-03  4.623172e-03
# 3       2.355581e-03  4.127494e-03 -8.944469e-04 -2.437741e-03 -1.906283e-03
# 4       1.069053e-02  1.779539e-02 -3.554730e-03 -1.837143e-02 -7.638443e-03
# 5       2.987710e-03  4.603134e-03 -2.441945e-03 -4.728206e-03 -3.857766e-03
# 6       1.659581e-02 -1.835091e-03 -4.013229e-04 -2.352247e-03 -2.973478e-03
# 7       2.034374e-02  2.905063e-02 -4.926250e-03 -4.284774e-02 -4.290474e-03
# 8       1.738771e-02  3.553512e-02 -2.268753e-02  7.157925e-03 -7.469877e-03
# 9       8.061360e-03  2.656042e-03 -1.501270e-03 -5.457477e-03  1.495324e-03
# 10      1.085362e-02  1.269406e-02 -6.126799e-03 -2.730167e-03 -2.389024e-03
# 11      3.578328e-02  3.613392e-02  5.378537e-03 -2.985780e-03 -4.584066e-03
# 12      1.175838e-01  1.116518e-01  1.831943e-01  3.612026e-02 -1.346377e-03
# 13      3.776126e-02  7.304644e-02 -4.334343e-02 -1.064869e-01 -6.409527e-02
# 14      1.710386e-02  2.286992e-02 -5.982072e-03 -3.189202e-02 -3.275351e-03
# 15      2.592289e-02  5.671430e-02 -2.311940e-02 -8.532633e-02 -9.796042e-02
# 16      4.233779e-03  1.123094e-02 -7.327523e-03 -6.899795e-03 -5.621608e-03
# 17      2.084783e-02  3.236932e-02 -6.828685e-03 -3.501505e-02 -1.033969e-02
# 18      4.321673e-02  2.006819e-01 -1.882357e-01  1.922401e-01  1.201749e-02
# 19      1.772306e-01 -7.603970e-02 -1.154942e-02  2.579114e-02 -2.433900e-03
# 20      5.345878e-03  1.426244e-02 -5.777030e-03 -1.111944e-02 -8.928302e-03
# 21      1.303782e-02  2.600650e-02 -1.456829e-02 -2.456261e-02 -1.055404e-03
# 22      7.959087e-02  3.863435e-01 -3.768719e-01  4.235214e-01  2.729601e-02
# 23      9.353679e-03  2.206671e-02  1.023791e-02 -1.220579e-02 -1.013032e-03
# 24      2.942436e-02  3.446552e-02 -1.788512e-02 -3.769579e-02 -1.953865e-02
# 25      2.383952e-02  2.588028e-02 -7.520034e-03 -3.091253e-02  3.514552e-02
# 26      1.575225e-02  2.726304e-03 -3.370591e-03 -4.206686e-03  3.216791e-03
# 27      2.256183e-02  2.306296e-02  1.096746e-02 -1.583530e-02 -6.725136e-03
# 28      5.488083e-01  2.440908e-01  6.123841e-01  2.169524e-01  9.006695e-02
# 29      1.485620e-02  1.611057e-03 -3.219396e-03 -9.472903e-03  1.751240e-03
# ...              ...           ...           ...           ...           ...
# 808550  2.671772e-01 -1.074812e-01 -2.619010e-02  3.066109e-02 -6.766088e-04
# 808551  1.460223e-02  5.796208e-03 -4.323123e-03 -4.354410e-03 -6.135410e-03
# 808552  1.638941e-02 -5.842908e-03 -1.778843e-03  1.566389e-04  1.509720e-05
# 808553  2.123691e-03  2.550071e-03 -3.794785e-04 -2.983860e-03 -1.746163e-03
# 808554  4.767825e-02  1.063560e-01  1.413036e-01  2.180899e-02  3.162125e-03
# 808555  3.776130e-02 -1.943056e-03  1.945179e-03 -8.598581e-03  8.827178e-03
# 808556  3.506787e-02  4.394417e-02 -1.357216e-02 -3.808124e-02 -7.503982e-03
# 808557  8.315997e-03  1.650316e-02 -2.823422e-03 -1.970195e-02 -2.052495e-02
# 808558  8.068405e-03  4.774914e-03 -8.784939e-04 -6.421612e-03 -2.182519e-03
# 808559  2.009332e-02  5.310532e-02 -2.665722e-02 -7.693333e-02 -4.955765e-02
# 808560  8.810124e-03  1.216678e-02 -3.609612e-03 -1.573157e-02 -8.896804e-03
# 808561  1.440605e-02  1.513723e-02 -1.861088e-04 -2.335693e-02 -1.345639e-02
# 808562  3.489944e-02  1.085364e-01 -8.041355e-02 -3.488497e-02 -7.764213e-02
# 808563  1.462710e-02  2.947539e-02 -9.161896e-03 -3.295054e-02 -3.587265e-02
# 808564  7.604491e-03  1.173203e-02 -4.410687e-03 -1.337036e-02 -8.211689e-03
# 808565  8.843895e-04  3.597800e-04 -9.214675e-05 -6.396139e-04  2.068135e-04
# 808566  4.791843e-35 -3.014160e-33  1.158538e-32 -4.408604e-32 -5.708086e-32
# 808567  4.271879e-02  1.535107e-01 -1.040896e-01 -6.814046e-02 -1.044273e-01
# 808568  1.015282e-02 -8.741842e-05 -2.005911e-03 -4.640065e-03  2.506883e-03
# 808569  5.243001e-02 -4.139506e-03  1.599605e-02  8.413251e-03  1.692909e-02
# 808570  3.345224e-03  2.488567e-03 -1.027133e-03 -4.082105e-03 -8.890163e-04
# 808571  2.239141e-03  3.613578e-03 -2.675651e-03 -1.494283e-03 -2.367878e-04
# 808572  6.795595e-03  1.030348e-02 -4.810829e-03 -1.081103e-02 -6.749678e-04
# 808573  2.005341e-02  9.335533e-03 -1.124669e-02 -1.637381e-02 -1.511027e-02
# 808574  2.857240e-03  4.778231e-03 -2.911357e-03 -3.929711e-03 -4.065040e-03
# 808575  4.269924e-02  9.553110e-03 -2.189184e-02 -3.408253e-03 -1.280554e-02
# 808576  4.396119e-02  5.102467e-02 -2.107685e-02 -1.159189e-01 -1.598667e-01
# 808577  1.839196e-04  3.621311e-04  1.286009e-05 -3.988075e-04 -7.935203e-05
# 808578  2.379726e-02  3.589966e-02 -8.890949e-03 -2.932111e-02 -1.073902e-02
# 808579  3.136408e-02  6.477554e-02 -3.689534e-02 -1.018333e-01 -5.991380e-02
#
#                   5             6             7             8             9   \
# 0      -7.742001e-02 -6.926516e-02 -5.348704e-02  5.028074e-02  3.764758e-02
# 1       9.343124e-04 -3.335021e-04 -4.106043e-04 -4.827665e-04  1.745946e-04
# 2       9.719917e-04  4.256813e-03 -3.937590e-03  9.983550e-04  1.952652e-03
# 3       1.978442e-04 -3.737661e-04 -2.806045e-03 -2.803741e-04  9.125670e-04
# 4       1.472501e-02  5.411817e-03 -2.655588e-03  6.015952e-03  1.153957e-02
# 5       1.131396e-03  4.084144e-03 -2.577614e-03 -2.395870e-03 -2.519960e-03
# 6      -6.618593e-03 -7.905342e-03 -3.776101e-03 -3.510457e-03  2.416071e-03
# 7      -3.770516e-03  6.332239e-02 -1.468954e-02  3.912068e-02  3.556305e-02
# 8      -2.626144e-03  6.312115e-03 -1.649819e-02  2.231267e-03 -6.863722e-03
# 9      -1.159475e-03  6.337332e-04 -3.887402e-03 -5.985051e-04  3.104985e-03
# 10      8.257012e-03  6.158230e-04 -3.171127e-03  1.259336e-04 -1.711061e-04
# 11      2.155574e-02  4.107060e-03 -3.789647e-03 -4.602856e-03 -6.936118e-04
# 12      6.736671e-02  2.300030e-01 -4.029807e-02  1.105898e-01 -1.874741e-02
# 13      5.017971e-02  5.698854e-02 -9.208932e-02 -1.382473e-01  2.214967e-01
# 14     -1.060031e-02  7.245240e-05  1.421746e-02  5.395362e-03  6.856783e-03
# 15     -9.639135e-02  6.232070e-02  1.343704e-01  8.869185e-03  1.765777e-02
# 16      3.721820e-03  7.359048e-03 -4.514366e-03 -1.727878e-03  4.090966e-03
# 17      2.068274e-02  1.717563e-02 -1.750237e-02 -2.067438e-02  1.804084e-02
# 18     -1.241866e-02 -2.757767e-02  7.528998e-03  4.411888e-02  3.294517e-02
# 19     -1.600494e-02 -2.780109e-02  8.861439e-03 -2.073396e-02  3.572002e-04
# 20      2.284598e-03  6.385568e-03 -9.758688e-03 -1.845941e-02  1.728137e-02
# 21      1.819998e-02  1.674048e-02 -2.044708e-02 -3.610141e-02  6.719061e-03
# 22     -1.665635e-02 -6.482531e-02  3.503645e-02  1.052799e-01  9.173859e-02
# 23      3.130126e-04  2.642212e-03 -4.323699e-03 -5.099165e-03  4.765004e-03
# 24      1.890478e-02  2.169472e-02 -2.665178e-02 -3.833554e-02  4.213714e-02
# 25     -3.251954e-03 -4.117555e-03  6.920071e-05  7.957436e-03  1.157284e-02
# 26      7.744130e-04  1.017748e-02 -5.444260e-03  7.756897e-03  1.956891e-03
# 27     -2.065082e-03 -3.755650e-03 -6.119576e-03 -5.750367e-03  8.538577e-03
# 28      4.322617e-02  5.293635e-02  1.214090e-01 -9.608115e-02 -3.049754e-02
# 29     -4.015975e-04  5.002221e-03 -1.076039e-03  1.747257e-03  5.458471e-03
# ...              ...           ...           ...           ...           ...
# 808550 -2.303123e-02 -5.359737e-02  1.483513e-02 -5.310436e-02 -3.950426e-03
# 808551 -1.055003e-03  4.380293e-03 -1.515598e-03  5.350999e-04  8.000640e-03
# 808552 -4.859412e-03 -7.730996e-03 -8.430471e-04 -3.611737e-03  1.256057e-03
# 808553 -7.445208e-04  1.998510e-04 -1.029359e-03 -6.825846e-04  1.133816e-03
# 808554  1.745870e-02  2.053675e-02  2.609543e-02 -3.111132e-02  1.666326e-02
# 808555  6.788245e-03  2.684820e-02  1.835306e-02 -5.783298e-02  1.905812e-02
# 808556  1.209912e-02  1.234627e-02 -1.199629e-02 -9.259861e-03  1.747325e-02
# 808557  2.530911e-02 -8.189598e-03 -6.488859e-03 -1.975898e-03 -1.198382e-02
# 808558  2.196297e-03  2.843448e-03 -3.417026e-03 -4.947081e-03  6.085318e-03
# 808559  3.879517e-02  3.546174e-02 -6.289941e-02 -1.237306e-01  2.049985e-01
# 808560  4.040956e-03  1.573288e-02 -1.989412e-02  3.889835e-03  1.060418e-02
# 808561 -1.070222e-02  6.584664e-04 -4.481702e-03  1.297985e-03  5.016100e-03
# 808562  2.113410e-02  5.154830e-02 -1.192012e-01 -1.551883e-01 -2.147682e-01
# 808563 -1.501623e-02  1.197191e-02  1.482367e-02 -1.592509e-03  2.334800e-02
# 808564 -4.158190e-03  3.795973e-03  2.177246e-03 -3.096292e-03  5.861029e-03
# 808565 -2.276330e-05  2.502399e-04 -1.422432e-04 -1.094894e-04  2.631086e-04
# 808566 -1.453286e-31 -1.409166e-31  3.639113e-31 -3.543757e-31 -7.568848e-31
# 808567  2.047081e-02  6.560965e-02 -1.394782e-01 -2.261405e-01  3.722894e-03
# 808568 -6.140177e-06  1.713026e-03 -2.575357e-04  7.933259e-04  2.893164e-03
# 808569  6.392758e-03  2.484108e-02  7.648588e-03  1.750428e-03 -9.957300e-03
# 808570 -1.631766e-03  1.476124e-03 -9.187503e-04 -2.084683e-04  1.438398e-03
# 808571 -8.592121e-04 -1.182948e-03 -1.631014e-03 -3.831191e-04  1.535215e-03
# 808572  1.965334e-03  5.405146e-03 -6.665306e-03 -1.383783e-03  8.289954e-03
# 808573 -1.387583e-02  7.735095e-03  1.228837e-02 -5.884645e-03 -1.532863e-03
# 808574  5.635788e-04  5.229884e-03 -3.794050e-03 -2.488301e-03 -5.118487e-03
# 808575  1.001618e-02  1.042808e-01 -5.647089e-02  7.363779e-02 -2.301436e-02
# 808576  3.239821e-01 -1.625998e-01  1.202673e-01  1.279264e-01 -5.121191e-02
# 808577 -8.995446e-05 -1.260952e-04 -2.695850e-04  1.657847e-04  6.691184e-05
# 808578  2.072584e-02  1.248845e-02 -1.029708e-02  1.044511e-02  9.240559e-03
# 808579  5.311550e-02  3.953000e-02 -8.089310e-02 -1.564240e-01  2.513039e-01
#
#                   10            11            12            13            14  \
# 0      -8.087608e-03 -4.696400e-02  7.760346e-02  3.333245e-02 -4.567070e-02
# 1       3.809545e-04 -1.051762e-03  5.417374e-04 -2.631184e-03  2.210105e-04
# 2       8.592784e-03 -1.532493e-03 -1.550577e-03 -4.008002e-03  1.729629e-03
# 3       1.016997e-03  1.977688e-03 -2.636045e-03  3.711229e-05  9.765975e-04
# 4       2.237750e-02 -2.773907e-02 -2.858122e-03 -1.735563e-02 -1.945317e-02
# 5       4.446547e-04  8.210045e-04  1.713261e-03 -1.011472e-03  8.183502e-06
# 6      -1.114094e-03 -8.106194e-03  6.382172e-03 -5.805720e-03  5.957806e-03
# 7       6.644650e-02 -1.022242e-01  4.841180e-02 -1.198682e-02  2.638374e-01
# 8       5.020518e-03 -3.129683e-03 -3.013763e-03  3.269674e-03  7.957256e-03
# 9      -4.776841e-04 -7.299434e-03  8.163086e-04 -1.461281e-03 -2.279617e-03
# 10      4.608993e-03 -8.238601e-03  4.574193e-03 -4.800403e-03  4.388590e-03
# 11      3.018892e-03 -1.969453e-02  1.325980e-02 -1.821410e-02  2.504431e-02
# 12     -7.373360e-02 -8.301015e-02 -6.356954e-02  1.685435e-01 -7.511602e-02
# 13     -6.209612e-02  8.237160e-02 -7.675299e-02  3.741255e-02  4.376737e-03
# 14      5.607913e-03 -6.374724e-03  3.552674e-04 -1.579595e-03 -5.258727e-03
# 15     -1.911563e-03  8.068196e-03 -4.543080e-02 -2.677722e-02 -1.838117e-02
# 16      1.600307e-03 -3.257302e-03  6.612493e-04 -1.266316e-02 -6.967434e-03
# 17     -1.199909e-03 -2.242983e-03 -2.691887e-03 -3.271514e-03 -3.563726e-03
# 18      6.961292e-03 -1.416941e-02 -1.225999e-02  1.059210e-02 -5.078876e-03
# 19     -1.881158e-02 -2.426107e-03  8.376130e-03 -9.135875e-03  1.512329e-02
# 20     -6.397589e-03  1.765019e-02 -3.281263e-03  1.115353e-02  6.681139e-03
# 21      9.714550e-03 -3.025929e-02 -1.832943e-02 -5.739668e-02 -2.944249e-02
# 22      1.872440e-02 -3.085057e-02 -4.774880e-02  8.264654e-04 -5.970789e-03
# 23      1.101186e-02 -8.286212e-03  5.110347e-03  2.458166e-04 -1.015742e-02
# 24      1.209762e-02 -2.048338e-02 -1.016651e-02 -3.698053e-02  4.725982e-03
# 25      5.857029e-04 -1.523610e-02  6.223502e-03 -6.819382e-03  1.258308e-02
# 26     -3.663576e-03 -1.141567e-02 -4.091460e-03  8.111576e-03  4.278531e-03
# 27      2.891515e-03 -1.280528e-02  1.288133e-02 -1.205170e-03 -6.087643e-03
# 28     -7.277984e-02  3.558259e-02  3.127756e-02  2.350399e-02 -2.718974e-02
# 29      6.904542e-03 -1.145283e-02  2.292401e-03 -9.104920e-03  1.674505e-02
# ...              ...           ...           ...           ...           ...
# 808550 -1.997740e-02 -1.689470e-03  5.100783e-03 -4.660384e-02  2.343701e-02
# 808551 -2.898495e-03 -4.044160e-03  2.665798e-03 -5.736047e-04  6.345670e-03
# 808552 -1.001290e-03 -2.511300e-03  1.357207e-03 -6.338344e-03  4.042155e-03
# 808553  3.510112e-03 -8.588026e-04  1.308207e-03  5.759369e-04 -1.689046e-04
# 808554 -1.229205e-02 -1.702094e-02  3.107527e-02 -9.291181e-03 -7.145394e-03
# 808555  4.101913e-01  5.800065e-02  2.889683e-02  1.165573e-01 -8.494060e-02
# 808556  1.703819e-02 -3.945354e-02  6.313067e-04 -3.496617e-02 -2.496812e-02
# 808557  2.308678e-03 -7.073107e-03 -3.003271e-03 -1.187713e-02 -8.871544e-03
# 808558 -1.048080e-03  1.360856e-03 -3.921539e-04  1.192581e-03  3.674577e-03
# 808559 -6.264180e-02  1.275933e-01 -4.289579e-02  7.270707e-02  2.322257e-02
# 808560  1.625613e-03 -2.296873e-02 -1.339152e-04 -4.415840e-03 -1.027695e-02
# 808561  2.202108e-02 -1.088102e-02 -1.503534e-02 -1.188416e-02 -3.536943e-03
# 808562 -1.497822e-02 -1.769333e-02  6.383462e-02 -3.299206e-02 -2.974640e-02
# 808563  9.831868e-03 -3.882641e-03 -1.411978e-02 -6.094626e-03 -8.510386e-03
# 808564  1.681158e-04 -2.124081e-03 -2.663118e-03 -2.768306e-03 -2.877341e-03
# 808565 -7.540594e-05 -3.259339e-04 -5.917708e-06  1.272271e-05  3.165070e-04
# 808566 -8.370096e-31 -6.574411e-31 -2.168422e-30 -1.150228e-30  1.051241e-30
# 808567 -9.549617e-02  2.074635e-01  6.493814e-02  1.714276e-01  6.394456e-02
# 808568  2.916207e-03 -4.776726e-03  2.987793e-04 -6.127807e-03  4.104616e-03
# 808569  1.028543e-02  1.492304e-02 -1.355938e-02  2.249724e-02 -1.480850e-02
# 808570  7.295985e-04 -1.847271e-03  2.162159e-03 -4.839968e-04  5.951991e-03
# 808571 -5.621181e-04 -5.678586e-04  2.179062e-03  1.188647e-03 -1.731821e-04
# 808572  2.195866e-03 -6.327425e-03 -2.018692e-03  7.624106e-04  8.664286e-04
# 808573 -1.761313e-03 -4.884742e-03 -6.009989e-03 -2.048987e-02 -2.271363e-04
# 808574  5.457369e-05  1.493860e-03  3.513798e-03 -1.074140e-03 -5.010399e-04
# 808575 -2.895917e-02 -3.769620e-02 -3.814633e-02  7.540824e-02 -3.249078e-02
# 808576 -6.952850e-03  2.502739e-02  1.869823e-02  5.176193e-02  3.756038e-03
# 808577  2.879379e-04 -2.407471e-04 -1.597687e-04 -1.962724e-04 -1.239096e-04
# 808578  2.540416e-02 -3.315644e-02 -3.883875e-03 -1.804664e-02 -1.817970e-02
# 808579 -7.613974e-02  1.471926e-01 -5.352590e-02  8.175060e-02  3.761068e-02
#
#                   15            16            17            18            19
# 0      -2.636334e-02  8.854023e-03 -5.102415e-04  1.450441e-02 -1.468149e-02
# 1       2.270042e-04  2.994143e-03 -1.275553e-04 -1.641909e-03  9.521732e-04
# 2       1.000965e-02  1.891700e-03 -1.027816e-04  1.598047e-02  1.740534e-02
# 3       3.306780e-03  2.719538e-03 -1.773992e-03  3.248239e-03 -2.015097e-03
# 4       1.039797e-01  7.561531e-03 -5.262503e-02 -8.317795e-03 -5.293925e-02
# 5       4.309930e-03  3.624933e-03 -1.709766e-03  2.461311e-03  4.304095e-03
# 6       1.036956e-02 -3.259541e-03 -3.583025e-03 -4.548027e-03  5.808575e-03
# 7      -5.295488e-02  2.607920e-02 -3.589462e-02  2.407111e-03 -1.603788e-02
# 8       3.105990e-02  6.390757e-04 -1.676654e-02  1.869366e-02  2.741236e-02
# 9       1.359476e-04  5.839375e-03 -5.925380e-03  4.442532e-03  2.564685e-02
# 10     -1.797295e-03  2.254556e-02 -6.211046e-03  7.178658e-03  3.437069e-02
# 11      9.028675e-03  4.430691e-02 -7.417869e-03 -5.773492e-03  6.751413e-02
# 12     -2.283336e-02  3.034200e-02  5.949967e-02 -3.794686e-02 -1.054451e-01
# 13     -5.381725e-02 -1.209164e-01  2.741695e-02  1.220352e-02 -5.212271e-02
# 14      1.674441e-02 -4.629600e-03 -4.459587e-03  5.145705e-03  1.547708e-02
# 15      2.569141e-02  1.573431e-02 -1.214120e-02  9.992732e-03  8.060431e-02
# 16     -4.701443e-03  2.355045e-02  2.780877e-03 -8.915804e-03  4.701733e-02
# 17     -6.382284e-03  3.420597e-03 -6.348044e-03 -1.180713e-02  9.226383e-03
# 18     -3.956500e-03 -1.488910e-02  2.023249e-03  3.913224e-03 -1.268282e-02
# 19      2.522865e-03 -9.493816e-03  7.276632e-03 -3.995128e-02  4.471004e-03
# 20      1.287767e-03  1.870945e-04 -9.566186e-03 -5.498011e-04  1.109571e-02
# 21     -4.104884e-02  9.773508e-02 -1.587396e-02  6.700494e-03  1.035081e-01
# 22     -4.597980e-02 -6.085286e-03  1.018285e-02  5.373265e-03 -4.080491e-02
# 23      2.017158e-02  2.595200e-03  1.850767e-02 -1.054847e-03 -3.235978e-03
# 24      6.228873e-02  3.065093e-02  1.948536e-01  1.248342e-01  3.497746e-02
# 25      4.360356e-03 -1.677724e-02  1.171360e-02 -1.208272e-02  1.601127e-02
# 26      4.214484e-03 -9.397429e-04  2.061566e-03 -8.889625e-03  1.215629e-02
# 27      2.220931e-02  2.101369e-03  2.392996e-02 -4.459536e-03  2.124306e-03
# 28     -8.055269e-02  3.083289e-02 -1.193428e-01  1.792746e-01 -6.528889e-02
# 29      1.412592e-02 -9.473305e-03 -1.493368e-02  8.194200e-03 -1.871326e-03
# ...              ...           ...           ...           ...           ...
# 808550  2.826537e-02 -3.876747e-03 -9.163322e-03 -3.584489e-02  5.609713e-02
# 808551  1.032515e-02 -2.649896e-04  3.010395e-03 -9.102721e-03  3.036002e-03
# 808552  3.328061e-03 -6.997759e-04 -3.731035e-03 -5.474986e-03  1.221993e-02
# 808553  2.919839e-03 -6.411680e-04 -2.444220e-04  7.678595e-04  1.383730e-03
# 808554  2.622333e-03 -7.224564e-03  7.786847e-03 -5.472835e-03 -4.397746e-02
# 808555 -3.981808e-02 -2.255410e-02  3.489175e-02 -4.455285e-02  6.190223e-03
# 808556  9.041532e-02  3.763907e-02 -5.642074e-02 -3.154215e-03  3.245303e-02
# 808557 -9.358394e-03  3.893360e-02  9.058990e-03 -1.589578e-02 -1.366495e-02
# 808558  5.190127e-03  9.344134e-04 -2.211543e-03 -8.193873e-04  1.733615e-04
# 808559 -3.336442e-02 -1.130103e-02 -1.414760e-02 -1.231311e-02 -4.047118e-02
# 808560  1.458731e-02  4.730837e-02  1.031924e-02 -5.169738e-02  2.611478e-02
# 808561  1.441383e-02 -4.071514e-02 -4.934335e-03  3.700826e-03  8.962045e-03
# 808562 -5.913247e-02 -6.843160e-02 -3.815513e-02 -1.140661e-02 -2.364271e-03
# 808563  5.227675e-02  2.885244e-03 -2.466905e-02  2.690402e-02  6.959383e-02
# 808564  4.440851e-03  4.107871e-03  2.090344e-03 -3.834001e-04  3.091285e-03
# 808565  5.362865e-04  7.441312e-05 -1.738110e-04  7.663085e-05  9.121638e-04
# 808566  1.974600e-31 -4.514851e-30 -1.733281e-30 -3.217688e-30 -9.282765e-30
# 808567  1.213704e-02 -3.138359e-02 -3.795280e-02 -2.806254e-02 -2.474455e-02
# 808568  1.212910e-02 -7.448326e-03 -8.971927e-03  4.622378e-03 -1.187181e-03
# 808569 -3.287272e-02  3.213332e-02 -7.467520e-02  1.305743e-01 -2.229080e-02
# 808570  1.887134e-04 -1.585601e-03 -1.091019e-03 -1.242454e-03  2.448705e-03
# 808571  1.198027e-03  4.287436e-05  2.651900e-04  1.237521e-03  1.291919e-03
# 808572  1.007338e-02  2.991104e-03  2.096335e-02  1.189234e-02 -2.519206e-03
# 808573  5.860655e-03 -5.975701e-03  6.016718e-03 -1.967873e-02  3.165988e-02
# 808574  2.602637e-03  5.207209e-03 -2.020292e-03  1.579316e-03  1.752468e-03
# 808575  1.644701e-02 -2.213476e-02  2.996679e-02 -7.951546e-02  2.705856e-02
# 808576 -6.479520e-02  2.171607e-02  1.413527e-02 -2.120408e-03  7.089553e-03
# 808577  1.081318e-03  1.230301e-04 -3.537769e-04  4.675636e-05 -2.582552e-04
# 808578  1.152702e-01  8.332678e-03 -6.036542e-02 -5.159669e-03 -3.808170e-02
# 808579 -3.061115e-02 -2.462291e-02  3.702051e-02  1.139333e-02 -6.437761e-02
#
# [808580 rows x 20 columns]

# %%
#Add these TFIDF reduced vector "distance" as new features
label = data['is_duplicate']
vector_train_q1 = tfidf_vec[0:len(train_data_q1)].reset_index(drop=True)
vector_train_q2 = tfidf_vec[len(train_data_q1):].reset_index(drop=True)

# %%
tfidf_train_vector = np.abs(vector_train_q1.values-vector_train_q2.values)
tfidf_train_vector = pd.DataFrame(tfidf_train_vector)
tfidf_train_vector.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.024785  0.014499  0.005289  0.039209  0.030550  0.074825  0.068535
# 1  0.015926  0.031288  0.003161  0.044891  0.032086  0.027252  0.008122
# 2  0.005597  0.012706  0.000999  0.001986  0.004950  0.000900  0.005752
# 3  0.007461  0.007469  0.006136  0.005822  0.002102  0.010882  0.005465
# 4  0.005218  0.011302  0.004071  0.022171  0.030810  0.024185  0.008516
#
#          7         8         9         10        11        12        13  \
# 0  0.047637  0.045847  0.036778  0.010183  0.044094  0.083496  0.033401
# 1  0.006030  0.012963  0.012971  0.013387  0.015447  0.045706  0.012470
# 2  0.000910  0.004397  0.002553  0.009677  0.004252  0.001365  0.011414
# 3  0.001904  0.004542  0.000652  0.005222  0.013176  0.006512  0.005311
# 4  0.018198  0.008911  0.023802  0.011349  0.025332  0.018339  0.009487
#
#          14        15        16        17        18        19
# 0  0.048760  0.030577  0.008906  0.000151  0.009603  0.018060
# 1  0.002271  0.046831  0.006964  0.015689  0.023785  0.059361
# 2  0.003539  0.005577  0.000194  0.006401  0.009523  0.011032
# 3  0.004124  0.004322  0.020819  0.007876  0.001799  0.026574
# 4  0.006498  0.038974  0.003468  0.021700  0.039409  0.138443

# %%
new_data = pd.concat([data, tfidf_train_vector], axis=1)
new_data.head()
# Out:
#                                            question1  \
# 0  [step, step, guide, invest, share, market, india]
# 1               [story, kohinoor, kohinoor, diamond]
# 2  [increase, speed, internet, connection, using,...
# 3                          [mentally, lonely, solve]
# 4  [one, dissolve, water, quikly, sugar, salt, me...
#
#                                            question2  is_duplicate  len_q1  \
# 0         [step, step, guide, invest, share, market]             0       7
# 1  [would, happen, indian, government, stole, koh...             0       4
# 2         [internet, speed, increased, hacking, dns]             0       6
# 3  [find, remainder, math, twentythree, twentyfou...             0       3
# 4                [fish, would, survive, salt, water]             0      10
#
#    len_q2  diff_len  common_words  len_char_q1  len_char_q2  ratio    ...     \
# 0       6         1             5           15           15     92    ...
# 1       9        -5             2           12           20     59    ...
# 2       5         1             2           14           13     55    ...
# 3       8        -5             0           10           17     20    ...
# 4       5         5             2           22           14     43    ...
#
#          10        11        12        13        14        15        16  \
# 0  0.010183  0.044094  0.083496  0.033401  0.048760  0.030577  0.008906
# 1  0.013387  0.015447  0.045706  0.012470  0.002271  0.046831  0.006964
# 2  0.009677  0.004252  0.001365  0.011414  0.003539  0.005577  0.000194
# 3  0.005222  0.013176  0.006512  0.005311  0.004124  0.004322  0.020819
# 4  0.011349  0.025332  0.018339  0.009487  0.006498  0.038974  0.003468
#
#          17        18        19
# 0  0.000151  0.009603  0.018060
# 1  0.015689  0.023785  0.059361
# 2  0.006401  0.009523  0.011032
# 3  0.007876  0.001799  0.026574
# 4  0.021700  0.039409  0.138443
#
# [5 rows x 38 columns]

# %%
# new_data.to_csv('finaldata.csv')

# %%
unwanted_columns = ['question1', 'question2']

tfidf_training_data = new_data.drop(unwanted_columns, axis=1)
X = tfidf_training_data.drop(['is_duplicate'], axis=1)
Y = tfidf_training_data['is_duplicate']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()), ('LR', LogisticRegression())])))
pipelines.append(('ScaledRF', Pipeline([('Scaler', StandardScaler()), ('RF', RandomForestClassifier())])))
pipelines.append(('ScaledXG', Pipeline([('Scaler', StandardScaler()), ('XG', XGBClassifier())])))

results = []
names = []

for name, model in pipelines:
    kfold = KFold(n_splits=10, random_state=42)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ScaledLR: -0.520244 (0.002672)
# ScaledRF: -0.782523 (0.017344)
# ScaledXG: -0.480573 (0.002681)

# %% [markdown]
# Over here with our new features all three model improve. Yet again the XGBClassifier performed better than all the others hence we can further tune is with same hyperparameters as before.

# %%
# xgboostclassifier
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)

kfold = KFold(n_splits=10, random_state=42)

max_depth = [3, 4, 5, 6, 7, 8]
min_child_weight = [1, 2, 3, 4]
param_grid = dict(max_depth=max_depth, min_child_weight=min_child_weight)

model = XGBClassifier()

grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(scaled_X_train, y_train)

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.447165 using {'max_depth': 8, 'min_child_weight': 1}
# -0.480679 (0.002515) with: {'max_depth': 3, 'min_child_weight': 1}
# -0.480633 (0.002740) with: {'max_depth': 3, 'min_child_weight': 2}
# -0.480638 (0.002610) with: {'max_depth': 3, 'min_child_weight': 3}
# -0.480694 (0.002505) with: {'max_depth': 3, 'min_child_weight': 4}
# -0.471082 (0.002407) with: {'max_depth': 4, 'min_child_weight': 1}
# -0.471013 (0.002593) with: {'max_depth': 4, 'min_child_weight': 2}
# -0.470857 (0.002262) with: {'max_depth': 4, 'min_child_weight': 3}
# -0.471068 (0.002653) with: {'max_depth': 4, 'min_child_weight': 4}
# -0.463970 (0.002792) with: {'max_depth': 5, 'min_child_weight': 1}
# -0.464035 (0.002525) with: {'max_depth': 5, 'min_child_weight': 2}
# -0.463936 (0.002541) with: {'max_depth': 5, 'min_child_weight': 3}
# -0.464001 (0.002473) with: {'max_depth': 5, 'min_child_weight': 4}
# -0.457426 (0.002613) with: {'max_depth': 6, 'min_child_weight': 1}
# -0.457420 (0.002479) with: {'max_depth': 6, 'min_child_weight': 2}
# -0.457406 (0.002918) with: {'max_depth': 6, 'min_child_weight': 3}
# -0.457627 (0.002685) with: {'max_depth': 6, 'min_child_weight': 4}
# -0.451938 (0.002671) with: {'max_depth': 7, 'min_child_weight': 1}
# -0.451978 (0.002580) with: {'max_depth': 7, 'min_child_weight': 2}
# -0.451898 (0.002761) with: {'max_depth': 7, 'min_child_weight': 3}
# -0.452096 (0.002709) with: {'max_depth': 7, 'min_child_weight': 4}
# -0.447165 (0.002792) with: {'max_depth': 8, 'min_child_weight': 1}
# -0.447609 (0.002735) with: {'max_depth': 8, 'min_child_weight': 2}
# -0.447730 (0.002758) with: {'max_depth': 8, 'min_child_weight': 3}
# -0.447809 (0.002795) with: {'max_depth': 8, 'min_child_weight': 4}

# %% [markdown]
# An increase in 0.02 from 0.467980 to 0.447165 with the new features from the tf-idfvectorizer. As mentioned above likely to do better with a higher `max_depth` argument. Lets go ahead and see how to performes on the validation set

# %%
# prepare the final model
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)

model = XGBClassifier(max_depth=8, min_child_weight=1, random_state=42)
model.fit(scaled_X_train, y_train)

scaled_X_valid = scaler.transform(X_valid)
predictions = model.predict_proba(scaled_X_valid)
print(log_loss(y_valid, predictions))
# Out:
# 0.449716341293

# %% [markdown]
# It performed well. No overfitting here. The model can be improved with better hyperparameter tuning. Maybe it can be improved with a neural network which is tackled in the Recurrent Neural Network (LSTM).ipynb file.
